# %%
import time, sys

import numpy as np
import pandas as pd

sys.path.append('/home/yilingh/SI-Interaction')

from selectinf.Simulation.H1.nonlinear_H1_helpers import *

# %%
from operator import le, ge
def filter_pval_dict_new(target_dict, threshold=0.05, operator=le, p_flag="pivot"):
    grouped_targets = pd.DataFrame(target_dict).groupby(['parameter', 'method'])
    filtered_dict = {}
    # Filter by 
    for name, group in grouped_targets:
        # Subset the selected targets
        selected_targets_id = operator(np.abs(group['target']), threshold)
        selected_targets = group[p_flag][selected_targets_id]
        # Then filtered_dict.keys must be a dictionary
        if name[0] in filtered_dict.keys():
            filtered_dict[name[0]][name[1]] = selected_targets.tolist()
        else:
            filtered_dict[name[0]] = {}
            filtered_dict[name[0]][name[1]] = selected_targets.tolist()
        
    return filtered_dict
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_MSE(oper_char):
    specific_method = "MLE"  # Replace with the name of your method
    
    # Create a modified DataFrame
    df_modified = oper_char.copy()
    
    # For the specific method, keep "tau" values separate
    # For other methods, set "tau" to a single category, e.g., "All"
    df_modified['prop'] = df_modified.apply(
        lambda row: row['prop'] if row['method'] == specific_method else 'Naive/DS', axis=1
    )
    
    # Plotting
    sns.boxplot(x='method', y='MSE', hue='prop', data=df_modified, showmeans=True)
    plt.xlabel("Method")
    plt.ylabel("MSE")
    plt.title("Boxplot of MSE by Method and prop")
    plt.show()

# %% [markdown]
# # Simulation: vary correlation between features

# %%
def predict(beta_hat, X_test):
    return X_test.dot(beta_hat)

def generate_test(Y_mean, noise_sd):
    n = Y_mean.shape[0]
    Y_test = Y_mean + np.random.normal(size=(n,), scale=noise_sd)
    
    return Y_test

# %%
# A dictionary recording simulation results and metrics
oper_char = {}
oper_char["coverage rate"] = []
oper_char["avg length"] = []
oper_char["method"] = []
#oper_char["MSE"] = []
oper_char["prop"] = []
oper_char["rho"] = []
oper_char["sd_y"] = []
oper_char["main signal"] = []
oper_char["target"] = []
oper_char["power"] = []

MSE_dict = {}
MSE_dict["MSE"] = []
MSE_dict["method"] = []
MSE_dict["sd_y"] = []

# Dictionary of projected targets, over all simulation parameters
target_dict = {}
target_dict["parameter"] = []
target_dict["target"] = []
target_dict["target id"] = []
target_dict["method"] = []
target_dict["index"] = []
target_dict["pivot"] = []
target_dict["pval"] = []

# A dictionary recording p-values for each true interaction
# over all simulation results.
# Each simulation parameter (here parameter_list contain a list of main signal strengths 
# to be considered) has a corresponding dictionary of results
parameter_list = np.array([8, 4, 2, 1])#np.array([0.5, 2, 5, 10])
pval_dict = {}
for x in parameter_list:
    pval_dict[x] = {}
    for m in ['Naive', 'Data Splitting', 'MLE']:
        pval_dict[x][m] = []

# Group lasso solver constructor
const = group_lasso.gaussian
active_inter_list_true = np.array([[0,1], [1,2], [2,4], [1,5], [2,6]])
active_inter_list_true_list = [(x[0],x[1]) for x in active_inter_list_true]

#p = 50
rho = 0.5 # Correlation of signal covariates (amongst themselves), and noise.
sig = 2  # Controlling interaction vs main signals. 
           # Setting it this way generates comparable main 
           # and interaction signals (sig = 2 works )
weights = 0.05 # Group Lasso weights
s_inter = 5 # Number of true interactions
p_nl = 20 # Number of nonlinear covariates
n=200
root_n_scaled = False
main_sig = 2
prop=0.9

ds_rank_def_count = {sd_y: 0 for sd_y in parameter_list}

for sd_y in parameter_list:
    for i in range(500):
        np.random.seed(i+1000)
        #MSE_set = False
        
        print(sd_y, i,"th simulation done")
        print("seed:", i+1000)
        # Generating a (X, Y) pair, and corresponding basis expansion
        # The 'weakhierarchy' argument is overridden by setting 
        # `active_inter_list`.
        (design, data_interaction, Y, Y_mean, data_combined,
         groups, active, active_inter_adj, active_inter_list, gamma) \
            = (generate_gaussian_instance_nonlinear_interaction_simple
               (n=n, p_nl=p_nl, rho=rho, full_corr=False, rho_noise=rho,
                SNR = None, main_signal=main_sig, noise_sd=sd_y,
                nknots = 6, degree = 2, interaction_signal=sig,
                random_signs=False, scale=root_n_scaled, center=False,
                structure='weakhierarchy', s_interaction=s_inter,
                intercept=True, active_inter_list=active_inter_list_true, 
                return_gamma=True))
        print("SD(Y): ", np.std(Y))
        Y_test = Y_mean + np.random.normal(size=(n,), scale=sd_y)
        
        # Performing Naive inference using 'all pairs'
        (coverages, lengths, selected_inter, p_values, pivots, targets, idx, 
        beta_hat_naive) \
            = naive_inference_inter(X=design, Y=Y, groups=groups,
                                    Y_mean=Y_mean, const=const,
                                    n_features=20, interactions=data_interaction,
                                    weight_frac=weights, level=0.9, mode='weakhierarchy',
                                    solve_only=False, continued=False,
                                    parallel=False, p_val=True, 
                                    return_pivot=True, intercept=True, 
                                    target_ids=active_inter_list_true_list,
                                       root_n_scaled=root_n_scaled)
        
        noselection_naive = coverages is None
        
        if not noselection_naive:
            # Naive
            oper_char["coverage rate"].append(np.mean(coverages))
            oper_char["avg length"].append(np.mean(lengths))
            oper_char["method"].append('Naive')
            oper_char["sd_y"].append(sd_y)
            oper_char["main signal"].append(main_sig)
            oper_char["prop"].append(prop)
            oper_char["rho"].append(rho)
            #oper_char["MSE"].append(MSE_naive)
            #oper_char["SNR"].append(SNR)
            oper_char["target"].append(targets[0])
            pval_dict[sd_y]['Naive'] += (p_values)
            oper_char["power"].append(calculate_power(p_values, targets, 0.1))
            update_targets(dict=target_dict,
                           true_inter_list=active_inter_list_true_list,
                           targets=targets, parameter=sd_y,
                           method="Naive", idx=idx,
                           pvals=p_values,
                           pivots=pivots, sim_idx=i)
          
        # Continue if Naive yields a nonempty group lasso selection
        # (this is almost always the case)
        # Performing data splitting using 'all pairs'
        # DS solve only
        ds_rank_def = False
        (nonzero_ds, selected_groups_ds, subset_select_ds, beta_hat_ds) \
            = data_splitting_inter(X=design, Y=Y, groups=groups,
                                   Y_mean=Y_mean, const=const,
                                   n_features=20, interactions=data_interaction,
                                   proportion=prop,
                                   weight_frac=weights, level=0.9,
                                   mode='weakhierarchy',
                                   solve_only=True, continued=False,
                                   parallel=False, p_val=True,
                                   target_ids=active_inter_list_true_list,
                                   root_n_scaled=root_n_scaled)
        if nonzero_ds.sum() + 1 >= n-subset_select_ds.sum():
            ds_rank_def = True
            ds_rank_def_count[sd_y] += 1

        if not ds_rank_def:
            (coverages_ds, lengths_ds, selected_inter_ds,
             p_values_ds, pivots_ds, targets_ds, idx_ds, beta_hat_ds) \
                = data_splitting_inter(X=design, Y=Y, groups=groups,
                                       Y_mean=Y_mean, const=const,
                                       n_features=20, interactions=data_interaction,
                                       proportion=prop,
                                       weight_frac=weights, level=0.9,
                                       mode='weakhierarchy',
                                       solve_only=False, continued=True,
                                       parallel=False, p_val=True,
                                       target_ids=active_inter_list_true_list,
                                       root_n_scaled=root_n_scaled,
                                       subset_cont=subset_select_ds,
                                       nonzero_cont=nonzero_ds,
                                       selected_groups_cont=selected_groups_ds,
                                       soln_cont=beta_hat_ds)
            noselection_ds = coverages_ds is None
        
        if not noselection_ds:
            # Data splitting
            oper_char["coverage rate"].append(np.mean(coverages_ds))
            oper_char["avg length"].append(np.mean(lengths_ds))
            oper_char["method"].append('Data Splitting')
            oper_char["sd_y"].append(sd_y)
            oper_char["main signal"].append(main_sig)
            oper_char["prop"].append(prop)
            oper_char["rho"].append(rho)
            #oper_char["MSE"].append(MSE_ds)
            #oper_char["SNR"].append(SNR)
            oper_char["target"].append(targets_ds[0])
            pval_dict[sd_y]['Data Splitting'] += (p_values_ds)
            oper_char["power"].append(calculate_power(p_values_ds, targets_ds, 0.1))
            update_targets(dict=target_dict,
                           true_inter_list=active_inter_list_true_list,
                           targets=targets_ds, parameter=sd_y,
                           method="Data Splitting", idx=idx_ds,
                               pvals=p_values_ds,
                               pivots=pivots_ds, sim_idx=i)
        
        # Continue if data splitting yields a nonempty group lasso selection
        # (this is almost always the case)    
        # Performing MLE using 'all pairs'
        (coverages_MLE, lengths_MLE, selected_inter_MLE, p_values_MLE, 
         pivots_MLE, targets_MLE, idx_MLE, beta_hat_MLE)\
            = (MLE_inference_inter
               (X=design, Y=Y, Y_mean=Y_mean, groups=groups,
                n_features=p_nl, interactions=data_interaction,
                intercept=True, 
                #randomizer_sd_const=tau, 
                proportion=prop,
                weight_frac=weights,
                level=0.9, mode='weakhierarchy', solve_only=False, 
                continued=False, parallel=False, p_val=True, 
                target_ids=active_inter_list_true_list,
                root_n_scaled=root_n_scaled))
        noselection_MLE = coverages_MLE is None
        
        # Collect results if all three methods yields 
        # nonempty first-stage selection
        if not noselection_MLE:
            # MLE
            oper_char["coverage rate"].append(np.mean(coverages_MLE))
            oper_char["avg length"].append(np.mean(lengths_MLE))
            oper_char["method"].append('MLE')
            oper_char["sd_y"].append(sd_y)
            oper_char["main signal"].append(main_sig)
            oper_char["prop"].append(prop)
            oper_char["rho"].append(rho)
            #oper_char["MSE"].append(MSE_MLE)
            #oper_char["SNR"].append(SNR)
            oper_char["target"].append(targets_MLE[0])
            pval_dict[sd_y]['MLE'] += (p_values_MLE)
            oper_char["power"].append(calculate_power(p_values_MLE, 
                                                      targets_MLE,
                                                      0.1))
            update_targets(dict=target_dict,
                           true_inter_list=active_inter_list_true_list,
                           targets=targets_MLE, parameter=sd_y,
                           method="MLE", idx=idx_MLE,
                               pvals=p_values_MLE,
                               pivots=pivots_MLE, sim_idx=i)
        
        # Set MSE  
        MSE_naive = np.mean((Y_test - predict(beta_hat_naive, design))**2)
        MSE_dict["MSE"].append(MSE_naive)
        MSE_dict["method"].append("Naive")
        MSE_dict["sd_y"].append(sd_y)
        
        MSE_ds = np.mean((Y_test - predict(beta_hat_ds, design))**2)
        MSE_dict["MSE"].append(MSE_ds)
        MSE_dict["method"].append("Data Splitting")
        MSE_dict["sd_y"].append(sd_y)
        
        MSE_MLE = np.mean((Y_test - predict(beta_hat_MLE, design))**2)
        MSE_dict["MSE"].append(MSE_MLE)
        MSE_dict["method"].append("MLE")
        MSE_dict["sd_y"].append(sd_y)
        MSE_set = True
# Out:
# 8 0 th simulation done
# seed: 1000
# Equally spaced quantile knots used.
# Main: 1.397236841166731
# Interaction: 1.8697846794548636
# induced SNR: 0.1360336852171138
# SD(Y):  8.462113274962958
# Naive Selected Groups: 4
# DS Selected Groups: 2
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 1 th simulation done
# seed: 1001
# Equally spaced quantile knots used.
# Main: 1.4917747953982479
# Interaction: 1.7933668730466161
# induced SNR: 0.1387140748407774
# SD(Y):  7.741271667750408
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 2 th simulation done
# seed: 1002
# Equally spaced quantile knots used.
# Main: 1.4313718771685646
# Interaction: 1.7180162464563637
# induced SNR: 0.11944052272637075
# SD(Y):  8.47786186548847
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 3 th simulation done
# seed: 1003
# Equally spaced quantile knots used.
# Main: 1.4560171861088211
# Interaction: 1.946031513666796
# induced SNR: 0.15088147142799752
# SD(Y):  8.054360991213953
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 4 th simulation done
# seed: 1004
# Equally spaced quantile knots used.
# Main: 1.4466442832695203
# Interaction: 1.6417757192923883
# induced SNR: 0.11582365173955222
# SD(Y):  8.59630996477707
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 5 th simulation done
# seed: 1005
# Equally spaced quantile knots used.
# Main: 1.4092688346203137
# Interaction: 1.9492147268502287
# induced SNR: 0.13998152392831487
# SD(Y):  8.539147430373546
# Naive Selected Groups: 9
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 8 6 th simulation done
# seed: 1006
# Equally spaced quantile knots used.
# Main: 1.396107366500288
# Interaction: 1.9861561924161535
# induced SNR: 0.14629405954265645
# SD(Y):  8.589806580047057
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 7 th simulation done
# seed: 1007
# Equally spaced quantile knots used.
# Main: 1.429669033914821
# Interaction: 1.81214740530396
# induced SNR: 0.12343562456021334
# SD(Y):  7.946509839050799
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 8 th simulation done
# seed: 1008
# Equally spaced quantile knots used.
# Main: 1.3854537197686512
# Interaction: 1.7177130593231278
# induced SNR: 0.11181275925865426
# SD(Y):  7.994786951505963
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 9 th simulation done
# seed: 1009
# Equally spaced quantile knots used.
# Main: 1.336081601952061
# Interaction: 1.921746011076309
# induced SNR: 0.1364625262656679
# SD(Y):  8.826794007518288
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 10 th simulation done
# seed: 1010
# Equally spaced quantile knots used.
# Main: 1.2986506538651084
# Interaction: 1.8994273396502008
# induced SNR: 0.1296386266205246
# SD(Y):  7.916114870608439
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 11 th simulation done
# seed: 1011
# Equally spaced quantile knots used.
# Main: 1.3400869782863485
# Interaction: 1.6526578803681333
# induced SNR: 0.11081000228673905
# SD(Y):  8.192299238920274
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 12 th simulation done
# seed: 1012
# Equally spaced quantile knots used.
# Main: 1.4187266002518895
# Interaction: 1.7298993057925252
# induced SNR: 0.11819283648454096
# SD(Y):  8.820483159146834
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 13 th simulation done
# seed: 1013
# Equally spaced quantile knots used.
# Main: 1.4034158742398017
# Interaction: 1.861093075684838
# induced SNR: 0.1372128081811748
# SD(Y):  8.706483826590365
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 14 th simulation done
# seed: 1014
# Equally spaced quantile knots used.
# Main: 1.412215551941769
# Interaction: 1.8317736011321055
# induced SNR: 0.12888793134512805
# SD(Y):  7.755976975943041
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 15 th simulation done
# seed: 1015
# Equally spaced quantile knots used.
# Main: 1.4625870178515457
# Interaction: 1.854130979003866
# induced SNR: 0.14006011794400758
# SD(Y):  8.12304761018352
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 16 th simulation done
# seed: 1016
# Equally spaced quantile knots used.
# Main: 1.4953324353140351
# Interaction: 1.885580273731749
# induced SNR: 0.14458578787723747
# SD(Y):  8.870280778460128
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 17 th simulation done
# seed: 1017
# Equally spaced quantile knots used.
# Main: 1.3554265719455523
# Interaction: 1.7615085378000996
# induced SNR: 0.12372470044344107
# SD(Y):  9.017521220332489
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 18 th simulation done
# seed: 1018
# Equally spaced quantile knots used.
# Main: 1.4213527935858914
# Interaction: 1.9243405681522183
# induced SNR: 0.1370993546755215
# SD(Y):  8.21019609848794
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 19 th simulation done
# seed: 1019
# Equally spaced quantile knots used.
# Main: 1.3803481625129828
# Interaction: 2.091944997056497
# induced SNR: 0.1438327946626328
# SD(Y):  8.237329204775579
# Naive Selected Groups: 8
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 20 th simulation done
# seed: 1020
# Equally spaced quantile knots used.
# Main: 1.435518201964189
# Interaction: 1.8972344026617192
# induced SNR: 0.13694892019316668
# SD(Y):  8.71678980257525
# DS Selected Groups: 2
# Data Carving Randomization Used
# 8 21 th simulation done
# seed: 1021
# Equally spaced quantile knots used.
# Main: 1.3996653038602165
# Interaction: 1.7555416893120348
# induced SNR: 0.12205508021272611
# SD(Y):  8.898434881709562
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 22 th simulation done
# seed: 1022
# Equally spaced quantile knots used.
# Main: 1.4429115204214789
# Interaction: 1.9441283162082932
# induced SNR: 0.13981126301407365
# SD(Y):  8.813853159322775
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 23 th simulation done
# seed: 1023
# Equally spaced quantile knots used.
# Main: 1.5052149971684483
# Interaction: 1.9728520516752577
# induced SNR: 0.15659449107959278
# SD(Y):  7.614493255443727
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 24 th simulation done
# seed: 1024
# Equally spaced quantile knots used.
# Main: 1.3201357780360188
# Interaction: 1.9257290057487273
# induced SNR: 0.13608212795436034
# SD(Y):  9.536890515947606
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 25 th simulation done
# seed: 1025
# Equally spaced quantile knots used.
# Main: 1.4270195184148304
# Interaction: 1.9060413044343545
# induced SNR: 0.13793037786801401
# SD(Y):  8.317629563210575
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 26 th simulation done
# seed: 1026
# Equally spaced quantile knots used.
# Main: 1.4216128362706129
# Interaction: 1.7719158907851347
# induced SNR: 0.1325148123710526
# SD(Y):  8.143782565429776
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 27 th simulation done
# seed: 1027
# Equally spaced quantile knots used.
# Main: 1.388647929300451
# Interaction: 1.7398486870578573
# induced SNR: 0.11367957944811628
# SD(Y):  7.946209871831542
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 28 th simulation done
# seed: 1028
# Equally spaced quantile knots used.
# Main: 1.4106541983426168
# Interaction: 1.9634002101799266
# induced SNR: 0.1455707791212063
# SD(Y):  8.977199550561567
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 29 th simulation done
# seed: 1029
# Equally spaced quantile knots used.
# Main: 1.3743545076074228
# Interaction: 1.784720453370937
# induced SNR: 0.1282381863944344
# SD(Y):  8.343498713492947
# Naive Selected Groups: 5
# DS Selected Groups: 2
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 30 th simulation done
# seed: 1030
# Equally spaced quantile knots used.
# Main: 1.393796581823078
# Interaction: 2.0406378344055964
# induced SNR: 0.14401923260419144
# SD(Y):  8.549024717993047
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 31 th simulation done
# seed: 1031
# Equally spaced quantile knots used.
# Main: 1.3146947822054487
# Interaction: 1.9428409511691507
# induced SNR: 0.13747222489903804
# SD(Y):  8.681858317680659
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 32 th simulation done
# seed: 1032
# Equally spaced quantile knots used.
# Main: 1.3651354485750566
# Interaction: 1.8286713556742529
# induced SNR: 0.12842934367396583
# SD(Y):  8.472001411846575
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# 8 33 th simulation done
# seed: 1033
# Equally spaced quantile knots used.
# Main: 1.4500446721217357
# Interaction: 1.7750920455413006
# induced SNR: 0.12789416124770508
# SD(Y):  8.789211052738755
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 34 th simulation done
# seed: 1034
# Equally spaced quantile knots used.
# Main: 1.4048730811824797
# Interaction: 1.6603602307524568
# induced SNR: 0.11262044277529279
# SD(Y):  8.052328116500657
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 35 th simulation done
# seed: 1035
# Equally spaced quantile knots used.
# Main: 1.4555898548267083
# Interaction: 1.7672915112508807
# induced SNR: 0.12557762402195002
# SD(Y):  8.301010793556506
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 36 th simulation done
# seed: 1036
# Equally spaced quantile knots used.
# Main: 1.3799261160285519
# Interaction: 1.8481304079238225
# induced SNR: 0.12886654430953992
# SD(Y):  7.657153655518953
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 37 th simulation done
# seed: 1037
# Equally spaced quantile knots used.
# Main: 1.4650842165051685
# Interaction: 1.9223854889052667
# induced SNR: 0.14553285826414045
# SD(Y):  7.578401611036521
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 38 th simulation done
# seed: 1038
# Equally spaced quantile knots used.
# Main: 1.4059035896967293
# Interaction: 1.7293085091192224
# induced SNR: 0.12265576776962211
# SD(Y):  8.57365027724388
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 39 th simulation done
# seed: 1039
# Equally spaced quantile knots used.
# Main: 1.3800890384952562
# Interaction: 1.7762926549084497
# induced SNR: 0.12345770976894568
# SD(Y):  7.94845539769407
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 40 th simulation done
# seed: 1040
# Equally spaced quantile knots used.
# Main: 1.4168888527998758
# Interaction: 1.901127251157363
# induced SNR: 0.13802971534183922
# SD(Y):  7.912825762950017
# Naive Selected Groups: 7
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 41 th simulation done
# seed: 1041
# Equally spaced quantile knots used.
# Main: 1.3806942677026424
# Interaction: 2.000682221949492
# induced SNR: 0.14304368886122215
# SD(Y):  8.625200436700547
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 42 th simulation done
# seed: 1042
# Equally spaced quantile knots used.
# Main: 1.3848800075733787
# Interaction: 1.750009868922205
# induced SNR: 0.11902719536926379
# SD(Y):  8.65262458324359
# Naive Selected Groups: 7
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 43 th simulation done
# seed: 1043
# Equally spaced quantile knots used.
# Main: 1.3470705824552704
# Interaction: 1.7511952812571667
# induced SNR: 0.12225155350957413
# SD(Y):  8.613583361271644
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 44 th simulation done
# seed: 1044
# Equally spaced quantile knots used.
# Main: 1.5271315323533243
# Interaction: 1.963608091593017
# induced SNR: 0.15840806606885488
# SD(Y):  8.423329624400319
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 45 th simulation done
# seed: 1045
# Equally spaced quantile knots used.
# Main: 1.4664810782702369
# Interaction: 1.8800040959800521
# induced SNR: 0.1384792580459608
# SD(Y):  8.67620001543852
# Naive Selected Groups: 6
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 46 th simulation done
# seed: 1046
# Equally spaced quantile knots used.
# Main: 1.3854725661035987
# Interaction: 1.9504415611039891
# induced SNR: 0.13710242583245977
# SD(Y):  8.372967317300034
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 47 th simulation done
# seed: 1047
# Equally spaced quantile knots used.
# Main: 1.4421980506948444
# Interaction: 1.8667066021173986
# induced SNR: 0.13539981279781207
# SD(Y):  7.546937064519637
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 48 th simulation done
# seed: 1048
# Equally spaced quantile knots used.
# Main: 1.2920146438652726
# Interaction: 1.7811397048542181
# induced SNR: 0.11633343417069258
# SD(Y):  8.90233256571499
# DS Selected Groups: 3
# Data Carving Randomization Used
# 8 49 th simulation done
# seed: 1049
# Equally spaced quantile knots used.
# Main: 1.5665155929728334
# Interaction: 1.7878023180154792
# induced SNR: 0.13771633108143605
# SD(Y):  8.33361038242872
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 50 th simulation done
# seed: 1050
# Equally spaced quantile knots used.
# Main: 1.354162713091847
# Interaction: 1.7163984192066046
# induced SNR: 0.11788602055373341
# SD(Y):  7.921682739255982
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 51 th simulation done
# seed: 1051
# Equally spaced quantile knots used.
# Main: 1.3134942631764903
# Interaction: 1.7940023222777686
# induced SNR: 0.11864958052264746
# SD(Y):  9.171567483726465
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 52 th simulation done
# seed: 1052
# Equally spaced quantile knots used.
# Main: 1.3716281632868086
# Interaction: 1.891071068250628
# induced SNR: 0.13278487547237136
# SD(Y):  8.519383219930843
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 53 th simulation done
# seed: 1053
# Equally spaced quantile knots used.
# Main: 1.4326803877936722
# Interaction: 1.8475833687650207
# induced SNR: 0.13304376099377582
# SD(Y):  9.207079452418068
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 54 th simulation done
# seed: 1054
# Equally spaced quantile knots used.
# Main: 1.367420887670567
# Interaction: 1.8766925982659581
# induced SNR: 0.12704807017574862
# SD(Y):  7.901727653677908
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 55 th simulation done
# seed: 1055
# Equally spaced quantile knots used.
# Main: 1.453199009525178
# Interaction: 1.7985655530473228
# induced SNR: 0.13397972912895023
# SD(Y):  7.793274687749048
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 56 th simulation done
# seed: 1056
# Equally spaced quantile knots used.
# Main: 1.4503940365624068
# Interaction: 2.0080958178228507
# induced SNR: 0.15388263592499773
# SD(Y):  8.08176797530476
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 57 th simulation done
# seed: 1057
# Equally spaced quantile knots used.
# Main: 1.42910258754514
# Interaction: 1.7956311386229598
# induced SNR: 0.12625358305799356
# SD(Y):  8.587853771826818
# Naive Selected Groups: 6
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 58 th simulation done
# seed: 1058
# Equally spaced quantile knots used.
# Main: 1.3334255003179736
# Interaction: 1.7853255799965857
# induced SNR: 0.12519508089142214
# SD(Y):  7.990746210191624
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 59 th simulation done
# seed: 1059
# Equally spaced quantile knots used.
# Main: 1.4056693569091883
# Interaction: 1.826145059553874
# induced SNR: 0.1333286155253167
# SD(Y):  8.91450102936312
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 60 th simulation done
# seed: 1060
# Equally spaced quantile knots used.
# Main: 1.3118204811618808
# Interaction: 1.8877058792941839
# induced SNR: 0.12825674822809763
# SD(Y):  8.334906033211679
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 61 th simulation done
# seed: 1061
# Equally spaced quantile knots used.
# Main: 1.4031762216875845
# Interaction: 1.838336369210888
# induced SNR: 0.12851123154287963
# SD(Y):  8.172482745007532
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 62 th simulation done
# seed: 1062
# Equally spaced quantile knots used.
# Main: 1.3786478410846366
# Interaction: 1.955036494856812
# induced SNR: 0.13540281725617845
# SD(Y):  8.764289552488327
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 63 th simulation done
# seed: 1063
# Equally spaced quantile knots used.
# Main: 1.453958241654691
# Interaction: 1.8707423186464676
# induced SNR: 0.13946356650719896
# SD(Y):  8.598104803629045
# Naive Selected Groups: 5
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 64 th simulation done
# seed: 1064
# Equally spaced quantile knots used.
# Main: 1.3732292797717083
# Interaction: 1.9551403479490812
# induced SNR: 0.13646504851234822
# SD(Y):  8.611634235441151
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 65 th simulation done
# seed: 1065
# Equally spaced quantile knots used.
# Main: 1.4583497766650357
# Interaction: 1.8650670678373729
# induced SNR: 0.13468696003408925
# SD(Y):  9.35165834476304
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 66 th simulation done
# seed: 1066
# Equally spaced quantile knots used.
# Main: 1.3314512966440786
# Interaction: 2.066681358425448
# induced SNR: 0.1525989741395513
# SD(Y):  9.268176353227078
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 67 th simulation done
# seed: 1067
# Equally spaced quantile knots used.
# Main: 1.2775641324668499
# Interaction: 1.8408751179802998
# induced SNR: 0.1169132189724112
# SD(Y):  7.86896518191021
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 68 th simulation done
# seed: 1068
# Equally spaced quantile knots used.
# Main: 1.4015061945082232
# Interaction: 1.9065637482977555
# induced SNR: 0.14198169452120926
# SD(Y):  8.275178386719045
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 8 69 th simulation done
# seed: 1069
# Equally spaced quantile knots used.
# Main: 1.4171438076167007
# Interaction: 1.8906863398118974
# induced SNR: 0.1368639621326916
# SD(Y):  8.533716544077055
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 70 th simulation done
# seed: 1070
# Equally spaced quantile knots used.
# Main: 1.3166826197050023
# Interaction: 1.9708289231127023
# induced SNR: 0.13496781819730802
# SD(Y):  8.524112898509028
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 71 th simulation done
# seed: 1071
# Equally spaced quantile knots used.
# Main: 1.4438208830328751
# Interaction: 1.951431157127521
# induced SNR: 0.1461832793431958
# SD(Y):  8.934748862461406
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 72 th simulation done
# seed: 1072
# Equally spaced quantile knots used.
# Main: 1.417261636150446
# Interaction: 1.8812879833980356
# induced SNR: 0.13916117193291605
# SD(Y):  8.266871015222357
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 73 th simulation done
# seed: 1073
# Equally spaced quantile knots used.
# Main: 1.4012011092725067
# Interaction: 1.9140497036275699
# induced SNR: 0.1380571516078277
# SD(Y):  8.308698969889988
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 74 th simulation done
# seed: 1074
# Equally spaced quantile knots used.
# Main: 1.3978942923837094
# Interaction: 1.863707440207583
# induced SNR: 0.13533960036398304
# SD(Y):  8.673678286453528
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 75 th simulation done
# seed: 1075
# Equally spaced quantile knots used.
# Main: 1.426558630221554
# Interaction: 1.9153494890325307
# induced SNR: 0.14052345881195666
# SD(Y):  8.492753884039002
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 76 th simulation done
# seed: 1076
# Equally spaced quantile knots used.
# Main: 1.3077051429604682
# Interaction: 1.742342584239846
# induced SNR: 0.10941737531489498
# SD(Y):  7.736342726955363
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 77 th simulation done
# seed: 1077
# Equally spaced quantile knots used.
# Main: 1.3431889425675605
# Interaction: 2.1018360673602103
# induced SNR: 0.15531923422607696
# SD(Y):  8.42067109129093
# Naive Selected Groups: 8
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 78 th simulation done
# seed: 1078
# Equally spaced quantile knots used.
# Main: 1.438292308013983
# Interaction: 1.9611253580578207
# induced SNR: 0.1446025983972191
# SD(Y):  8.986264611332619
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 79 th simulation done
# seed: 1079
# Equally spaced quantile knots used.
# Main: 1.473102772005732
# Interaction: 1.9044004555495522
# induced SNR: 0.1480073130961886
# SD(Y):  8.264048490435687
# DS Selected Groups: 2
# Data Carving Randomization Used
# 8 80 th simulation done
# seed: 1080
# Equally spaced quantile knots used.
# Main: 1.3319351482055795
# Interaction: 1.989933279895772
# induced SNR: 0.13535411472700054
# SD(Y):  8.679776960809294
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 81 th simulation done
# seed: 1081
# Equally spaced quantile knots used.
# Main: 1.387018580780057
# Interaction: 1.9480723935567448
# induced SNR: 0.1422365441399396
# SD(Y):  8.015894573213151
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 82 th simulation done
# seed: 1082
# Equally spaced quantile knots used.
# Main: 1.3926944510285038
# Interaction: 1.879605771839895
# induced SNR: 0.1355998132224325
# SD(Y):  8.60807096896624
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 83 th simulation done
# seed: 1083
# Equally spaced quantile knots used.
# Main: 1.3959162001045624
# Interaction: 1.743352588283723
# induced SNR: 0.12219716774572799
# SD(Y):  8.91073181081647
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 84 th simulation done
# seed: 1084
# Equally spaced quantile knots used.
# Main: 1.3643695213595814
# Interaction: 1.902784050870364
# induced SNR: 0.13250701906548112
# SD(Y):  8.08187160263065
# Naive Selected Groups: 5
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 85 th simulation done
# seed: 1085
# Equally spaced quantile knots used.
# Main: 1.4452431815865865
# Interaction: 1.9959557468723113
# induced SNR: 0.15155474835486182
# SD(Y):  8.620688753413724
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 86 th simulation done
# seed: 1086
# Equally spaced quantile knots used.
# Main: 1.4702512157790415
# Interaction: 1.8565523924747354
# induced SNR: 0.14361943957757045
# SD(Y):  9.037483496622203
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 87 th simulation done
# seed: 1087
# Equally spaced quantile knots used.
# Main: 1.4525540192440909
# Interaction: 2.011376489174079
# induced SNR: 0.14655898694650138
# SD(Y):  8.575909533885818
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 88 th simulation done
# seed: 1088
# Equally spaced quantile knots used.
# Main: 1.4161734269487605
# Interaction: 1.7364062307252814
# induced SNR: 0.12231547489377918
# SD(Y):  7.67566637234139
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 89 th simulation done
# seed: 1089
# Equally spaced quantile knots used.
# Main: 1.38939629581261
# Interaction: 1.8138570138156174
# induced SNR: 0.13113455042678282
# SD(Y):  8.071494829336446
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 90 th simulation done
# seed: 1090
# Equally spaced quantile knots used.
# Main: 1.3312432916012233
# Interaction: 1.8000648368028855
# induced SNR: 0.12035929978069966
# SD(Y):  8.656303004903423
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 91 th simulation done
# seed: 1091
# Equally spaced quantile knots used.
# Main: 1.339704952657967
# Interaction: 1.9586254828422451
# induced SNR: 0.13538602905984443
# SD(Y):  9.008210930137105
# Naive Selected Groups: 6
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 92 th simulation done
# seed: 1092
# Equally spaced quantile knots used.
# Main: 1.3720295098073634
# Interaction: 1.7307989488214162
# induced SNR: 0.11892806095798075
# SD(Y):  8.758934163607409
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 93 th simulation done
# seed: 1093
# Equally spaced quantile knots used.
# Main: 1.3524557826319898
# Interaction: 1.8540814470663616
# induced SNR: 0.12760353886367798
# SD(Y):  8.422307186449336
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 94 th simulation done
# seed: 1094
# Equally spaced quantile knots used.
# Main: 1.4401152219286
# Interaction: 1.9338676640797363
# induced SNR: 0.14270811560146682
# SD(Y):  8.304597413693278
# Naive Selected Groups: 8
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 95 th simulation done
# seed: 1095
# Equally spaced quantile knots used.
# Main: 1.3973473739974587
# Interaction: 1.909332279852436
# induced SNR: 0.13757741777921342
# SD(Y):  8.789941455425701
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 96 th simulation done
# seed: 1096
# Equally spaced quantile knots used.
# Main: 1.4029610430363197
# Interaction: 1.8933171515571652
# induced SNR: 0.13754791990814472
# SD(Y):  8.472948890683748
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 97 th simulation done
# seed: 1097
# Equally spaced quantile knots used.
# Main: 1.4155872454899538
# Interaction: 1.74683405187537
# induced SNR: 0.1247698758453213
# SD(Y):  8.377294488112314
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 98 th simulation done
# seed: 1098
# Equally spaced quantile knots used.
# Main: 1.2998312311579938
# Interaction: 1.6904019049702144
# induced SNR: 0.10791413064291186
# SD(Y):  8.182916012404533
# Data Carving Randomization Used
# 8 99 th simulation done
# seed: 1099
# Equally spaced quantile knots used.
# Main: 1.398586906846931
# Interaction: 1.8304005174153737
# induced SNR: 0.12819786155831286
# SD(Y):  8.559027939141835
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 100 th simulation done
# seed: 1100
# Equally spaced quantile knots used.
# Main: 1.4481485100015048
# Interaction: 1.7782158538420298
# induced SNR: 0.12763164681406217
# SD(Y):  8.556828989080039
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 101 th simulation done
# seed: 1101
# Equally spaced quantile knots used.
# Main: 1.3700777952439445
# Interaction: 1.8049585935790708
# induced SNR: 0.1212010772647256
# SD(Y):  8.526238817239326
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 102 th simulation done
# seed: 1102
# Equally spaced quantile knots used.
# Main: 1.3719641685870714
# Interaction: 1.9075868339648587
# induced SNR: 0.13537698724122904
# SD(Y):  8.245604122074486
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 103 th simulation done
# seed: 1103
# Equally spaced quantile knots used.
# Main: 1.3679704723443347
# Interaction: 1.879449638220306
# induced SNR: 0.12868130158648927
# SD(Y):  8.572604026119786
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 104 th simulation done
# seed: 1104
# Equally spaced quantile knots used.
# Main: 1.4350377182449807
# Interaction: 1.9704341889611503
# induced SNR: 0.1504134129019706
# SD(Y):  8.156417732579117
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 105 th simulation done
# seed: 1105
# Equally spaced quantile knots used.
# Main: 1.4256909403792781
# Interaction: 1.7184819818777972
# induced SNR: 0.11979125080934962
# SD(Y):  8.834977689154355
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 106 th simulation done
# seed: 1106
# Equally spaced quantile knots used.
# Main: 1.2557046711336015
# Interaction: 1.8101006287841255
# induced SNR: 0.11889439703878253
# SD(Y):  7.840155650245995
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 107 th simulation done
# seed: 1107
# Equally spaced quantile knots used.
# Main: 1.3318187015228495
# Interaction: 1.8554822128019082
# induced SNR: 0.12421709983406837
# SD(Y):  9.076292104218817
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 108 th simulation done
# seed: 1108
# Equally spaced quantile knots used.
# Main: 1.414760465997342
# Interaction: 1.8013838140444465
# induced SNR: 0.12694843701938208
# SD(Y):  7.995242101897841
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 109 th simulation done
# seed: 1109
# Equally spaced quantile knots used.
# Main: 1.5065849378061584
# Interaction: 1.9945123078650278
# induced SNR: 0.15693327340222454
# SD(Y):  8.421982266795792
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 110 th simulation done
# seed: 1110
# Equally spaced quantile knots used.
# Main: 1.4365855765470794
# Interaction: 1.836553194060987
# induced SNR: 0.13819332790724428
# SD(Y):  8.336806955305153
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 111 th simulation done
# seed: 1111
# Equally spaced quantile knots used.
# Main: 1.4005164723987276
# Interaction: 2.005741881939121
# induced SNR: 0.14213989857213463
# SD(Y):  8.532730997824153
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 112 th simulation done
# seed: 1112
# Equally spaced quantile knots used.
# Main: 1.4589066065867464
# Interaction: 1.8525277940067402
# induced SNR: 0.1331587087083905
# SD(Y):  8.229435321487346
# Naive Selected Groups: 6
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 113 th simulation done
# seed: 1113
# Equally spaced quantile knots used.
# Main: 1.4102749824278724
# Interaction: 1.8632939007472549
# induced SNR: 0.1351656298414529
# SD(Y):  8.648995691307938
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 114 th simulation done
# seed: 1114
# Equally spaced quantile knots used.
# Main: 1.4643861948579762
# Interaction: 1.8562714682261532
# induced SNR: 0.14174936768115232
# SD(Y):  9.777490794553467
# Naive Selected Groups: 8
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 115 th simulation done
# seed: 1115
# Equally spaced quantile knots used.
# Main: 1.4856437121949302
# Interaction: 1.9727765953863274
# induced SNR: 0.15679839148436073
# SD(Y):  8.309407381600172
# Naive Selected Groups: 8
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 116 th simulation done
# seed: 1116
# Equally spaced quantile knots used.
# Main: 1.3255321458670204
# Interaction: 1.9042818159537416
# induced SNR: 0.12772329092534446
# SD(Y):  7.927144817154275
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 117 th simulation done
# seed: 1117
# Equally spaced quantile knots used.
# Main: 1.3941247155456185
# Interaction: 1.884469818604759
# induced SNR: 0.13785677966881218
# SD(Y):  8.932828213446385
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 118 th simulation done
# seed: 1118
# Equally spaced quantile knots used.
# Main: 1.3530011092979015
# Interaction: 1.8733730575878285
# induced SNR: 0.13173962511335185
# SD(Y):  8.449592317365694
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 119 th simulation done
# seed: 1119
# Equally spaced quantile knots used.
# Main: 1.33692174872825
# Interaction: 1.8928952118904405
# induced SNR: 0.13310094556500876
# SD(Y):  8.278667606841783
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 120 th simulation done
# seed: 1120
# Equally spaced quantile knots used.
# Main: 1.4359605768610335
# Interaction: 1.8242333633725654
# induced SNR: 0.1308303643374392
# SD(Y):  8.642446682683483
# Naive Selected Groups: 8
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 121 th simulation done
# seed: 1121
# Equally spaced quantile knots used.
# Main: 1.43179513011871
# Interaction: 1.7808566971704374
# induced SNR: 0.12425404837543211
# SD(Y):  8.717074857267894
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 122 th simulation done
# seed: 1122
# Equally spaced quantile knots used.
# Main: 1.3514591164873968
# Interaction: 1.9023355923427259
# induced SNR: 0.12521475799060042
# SD(Y):  8.719333678525171
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 123 th simulation done
# seed: 1123
# Equally spaced quantile knots used.
# Main: 1.4033532079175184
# Interaction: 2.0683963326447907
# induced SNR: 0.1549302700344331
# SD(Y):  7.97320197435856
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 124 th simulation done
# seed: 1124
# Equally spaced quantile knots used.
# Main: 1.424642790492763
# Interaction: 2.012638429957862
# induced SNR: 0.1500218116651064
# SD(Y):  8.668975577735868
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 125 th simulation done
# seed: 1125
# Equally spaced quantile knots used.
# Main: 1.3231072153570895
# Interaction: 1.9901419591908922
# induced SNR: 0.13786496051899003
# SD(Y):  8.9631326167067
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 126 th simulation done
# seed: 1126
# Equally spaced quantile knots used.
# Main: 1.3830576964841592
# Interaction: 1.7508923692332692
# induced SNR: 0.12318889878899827
# SD(Y):  7.993048665934496
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 127 th simulation done
# seed: 1127
# Equally spaced quantile knots used.
# Main: 1.4435476470071922
# Interaction: 1.9691105188902982
# induced SNR: 0.15104522297560835
# SD(Y):  8.138554573698933
# Naive Selected Groups: 5
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 128 th simulation done
# seed: 1128
# Equally spaced quantile knots used.
# Main: 1.3128090665850625
# Interaction: 1.6615368921336202
# induced SNR: 0.108114820566925
# SD(Y):  8.888957470393791
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 129 th simulation done
# seed: 1129
# Equally spaced quantile knots used.
# Main: 1.4302320457401294
# Interaction: 1.80726591110372
# induced SNR: 0.12881547370301105
# SD(Y):  9.00044422682072
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 130 th simulation done
# seed: 1130
# Equally spaced quantile knots used.
# Main: 1.3698427134154734
# Interaction: 1.8733084728044627
# induced SNR: 0.13105026824160487
# SD(Y):  8.63737065737096
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 131 th simulation done
# seed: 1131
# Equally spaced quantile knots used.
# Main: 1.4940663915840804
# Interaction: 2.004045731988869
# induced SNR: 0.15212845196551542
# SD(Y):  9.209876964979177
# Naive Selected Groups: 3
# DS Selected Groups: 2
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 132 th simulation done
# seed: 1132
# Equally spaced quantile knots used.
# Main: 1.4499884154762623
# Interaction: 1.893840800494638
# induced SNR: 0.140676760125648
# SD(Y):  8.433314530816974
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 133 th simulation done
# seed: 1133
# Equally spaced quantile knots used.
# Main: 1.485484695183177
# Interaction: 1.9290292670809672
# induced SNR: 0.14876704724589615
# SD(Y):  8.301267042067098
# Naive Selected Groups: 5
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 134 th simulation done
# seed: 1134
# Equally spaced quantile knots used.
# Main: 1.3797123555904895
# Interaction: 1.7826837342886985
# induced SNR: 0.12507797281119795
# SD(Y):  8.041936470317781
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 135 th simulation done
# seed: 1135
# Equally spaced quantile knots used.
# Main: 1.4886169270521008
# Interaction: 2.0437778295076754
# induced SNR: 0.15135521038265737
# SD(Y):  9.107241084664475
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 136 th simulation done
# seed: 1136
# Equally spaced quantile knots used.
# Main: 1.3492964894829569
# Interaction: 1.8570960520167104
# induced SNR: 0.12906164572778023
# SD(Y):  8.500116299890388
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 137 th simulation done
# seed: 1137
# Equally spaced quantile knots used.
# Main: 1.443331158960726
# Interaction: 1.9870707338134908
# induced SNR: 0.15187578318769723
# SD(Y):  8.828454690172014
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 138 th simulation done
# seed: 1138
# Equally spaced quantile knots used.
# Main: 1.3456286270880962
# Interaction: 1.9427708504046743
# induced SNR: 0.13658441502776703
# SD(Y):  7.978527194133924
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 139 th simulation done
# seed: 1139
# Equally spaced quantile knots used.
# Main: 1.3672277945051268
# Interaction: 1.9619106225911052
# induced SNR: 0.13347667532390387
# SD(Y):  9.030768705951107
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 140 th simulation done
# seed: 1140
# Equally spaced quantile knots used.
# Main: 1.4076491720776712
# Interaction: 1.8799502660630605
# induced SNR: 0.1352131406638304
# SD(Y):  9.045094476657335
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 141 th simulation done
# seed: 1141
# Equally spaced quantile knots used.
# Main: 1.3053068994373958
# Interaction: 1.8206829380832656
# induced SNR: 0.11967099944414913
# SD(Y):  8.156284242039332
# Naive Selected Groups: 8
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 8 142 th simulation done
# seed: 1142
# Equally spaced quantile knots used.
# Main: 1.4437922608823164
# Interaction: 1.8690769892769905
# induced SNR: 0.14031603481147276
# SD(Y):  8.650193388027438
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 143 th simulation done
# seed: 1143
# Equally spaced quantile knots used.
# Main: 1.4726906322047888
# Interaction: 1.7912360233243707
# induced SNR: 0.12425962640339835
# SD(Y):  7.927833866432474
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 144 th simulation done
# seed: 1144
# Equally spaced quantile knots used.
# Main: 1.291287625801896
# Interaction: 1.8748673982743345
# induced SNR: 0.11926813776357273
# SD(Y):  8.117634818357502
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 145 th simulation done
# seed: 1145
# Equally spaced quantile knots used.
# Main: 1.4417715067421601
# Interaction: 1.7649476147561434
# induced SNR: 0.1242462660381521
# SD(Y):  8.164803138528574
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 146 th simulation done
# seed: 1146
# Equally spaced quantile knots used.
# Main: 1.38794103479496
# Interaction: 1.8434958548140663
# induced SNR: 0.13110170619321554
# SD(Y):  8.547704688552473
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 147 th simulation done
# seed: 1147
# Equally spaced quantile knots used.
# Main: 1.4719380593897
# Interaction: 1.8443061833000582
# induced SNR: 0.13251283461979785
# SD(Y):  8.5442249858619
# Naive Selected Groups: 3
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 148 th simulation done
# seed: 1148
# Equally spaced quantile knots used.
# Main: 1.3976702639100893
# Interaction: 1.7818092880296463
# induced SNR: 0.1257363929834338
# SD(Y):  8.10581763523095
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 149 th simulation done
# seed: 1149
# Equally spaced quantile knots used.
# Main: 1.3640438096855882
# Interaction: 1.7550123318614703
# induced SNR: 0.11790904788252861
# SD(Y):  8.416595074465732
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 150 th simulation done
# seed: 1150
# Equally spaced quantile knots used.
# Main: 1.4265372945096289
# Interaction: 1.8588951610332187
# induced SNR: 0.1406947160666531
# SD(Y):  8.49100074937709
# Naive Selected Groups: 3
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 151 th simulation done
# seed: 1151
# Equally spaced quantile knots used.
# Main: 1.364035667313024
# Interaction: 1.9122696560401338
# induced SNR: 0.13640317370150912
# SD(Y):  8.477842794891206
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 152 th simulation done
# seed: 1152
# Equally spaced quantile knots used.
# Main: 1.3786825070540236
# Interaction: 1.9185832654665596
# induced SNR: 0.13348241150555812
# SD(Y):  8.021952384392442
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 153 th simulation done
# seed: 1153
# Equally spaced quantile knots used.
# Main: 1.3773836469713372
# Interaction: 1.7990673222002342
# induced SNR: 0.12009446406298746
# SD(Y):  8.016384803592937
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 154 th simulation done
# seed: 1154
# Equally spaced quantile knots used.
# Main: 1.460684633269857
# Interaction: 2.036884523424879
# induced SNR: 0.1573923519971286
# SD(Y):  8.952178313325255
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 155 th simulation done
# seed: 1155
# Equally spaced quantile knots used.
# Main: 1.4046313472407375
# Interaction: 1.9236406814447633
# induced SNR: 0.13860138948953743
# SD(Y):  9.111522673938893
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 8 156 th simulation done
# seed: 1156
# Equally spaced quantile knots used.
# Main: 1.3923949621606757
# Interaction: 1.7526927915879769
# induced SNR: 0.12016861357053235
# SD(Y):  8.713545802849517
# Naive Selected Groups: 6
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 157 th simulation done
# seed: 1157
# Equally spaced quantile knots used.
# Main: 1.3414138180505781
# Interaction: 1.9139906255330876
# induced SNR: 0.13479845853448588
# SD(Y):  8.622378897352418
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# 8 158 th simulation done
# seed: 1158
# Equally spaced quantile knots used.
# Main: 1.3857489356055859
# Interaction: 1.8969727749238867
# induced SNR: 0.13212730521836363
# SD(Y):  8.237370901879201
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 159 th simulation done
# seed: 1159
# Equally spaced quantile knots used.
# Main: 1.4060118640433232
# Interaction: 1.8093525936107633
# induced SNR: 0.13279616504141886
# SD(Y):  9.530238168529035
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 160 th simulation done
# seed: 1160
# Equally spaced quantile knots used.
# Main: 1.4142370280319714
# Interaction: 1.974923713913924
# induced SNR: 0.14355106387541017
# SD(Y):  8.622198447323942
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 161 th simulation done
# seed: 1161
# Equally spaced quantile knots used.
# Main: 1.3834307925359315
# Interaction: 2.0272823760484417
# induced SNR: 0.15089663898801764
# SD(Y):  8.68115395111348
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 8 162 th simulation done
# seed: 1162
# Equally spaced quantile knots used.
# Main: 1.387306679841104
# Interaction: 1.6483504489136744
# induced SNR: 0.11455254516980833
# SD(Y):  8.105859925511755
# Naive Selected Groups: 5
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 163 th simulation done
# seed: 1163
# Equally spaced quantile knots used.
# Main: 1.433439589244408
# Interaction: 1.7860840685419248
# induced SNR: 0.13038324913468635
# SD(Y):  8.47010062935587
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 8 164 th simulation done
# seed: 1164
# Equally spaced quantile knots used.
# Main: 1.424581744487674
# Interaction: 1.9195514463233845
# induced SNR: 0.1434185228237186
# SD(Y):  8.965021657622767
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 8 165 th simulation done
# seed: 1165
# Equally spaced quantile knots used.
# Main: 1.4403478949469788
# Interaction: 1.9851200407747651
# induced SNR: 0.1485124686104755
# SD(Y):  8.083322682821105
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 8 166 th simulation done
# seed: 1166
# Equally spaced quantile knots used.
# Main: 1.3626628280513082
# Interaction: 1.925397771086237
# induced SNR: 0.13644679881824612
# SD(Y):  8.78489607900916
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 8 167 th simulation done
# seed: 1167
# Equally spaced quantile knots used.
# Main: 1.3112225272610953
# Interaction: 1.79650940530765
# ...
# 1 442 th simulation done
# seed: 1442
# Equally spaced quantile knots used.
# Main: 1.3630456134853162
# Interaction: 1.62804066305064
# induced SNR: 6.852514581620518
# SD(Y):  2.92149413463968
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 443 th simulation done
# seed: 1443
# Equally spaced quantile knots used.
# Main: 1.3069009407718706
# Interaction: 1.9053773678852293
# induced SNR: 8.01898433083989
# SD(Y):  2.985236701881445
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 444 th simulation done
# seed: 1444
# Equally spaced quantile knots used.
# Main: 1.4152179890600138
# Interaction: 1.8347434638517726
# induced SNR: 8.276304384993342
# SD(Y):  3.01881342360882
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 445 th simulation done
# seed: 1445
# Equally spaced quantile knots used.
# Main: 1.3977155477932472
# Interaction: 1.854493015333857
# induced SNR: 8.632273484781534
# SD(Y):  3.0480795408152375
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 446 th simulation done
# seed: 1446
# Equally spaced quantile knots used.
# Main: 1.3267341345405748
# Interaction: 1.689780921720197
# induced SNR: 7.149368782857344
# SD(Y):  2.8562780627432396
# Naive Selected Groups: 11
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 447 th simulation done
# seed: 1447
# Equally spaced quantile knots used.
# Main: 1.3986134682207996
# Interaction: 1.9741126142203818
# induced SNR: 9.447002693672518
# SD(Y):  3.2220125676852636
# Naive Selected Groups: 10
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 448 th simulation done
# seed: 1448
# Equally spaced quantile knots used.
# Main: 1.4049090122673042
# Interaction: 1.9400852353892333
# induced SNR: 8.721215829194573
# SD(Y):  3.1541063837168744
# Naive Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 449 th simulation done
# seed: 1449
# Equally spaced quantile knots used.
# Main: 1.4648144839383144
# Interaction: 1.8751045129397097
# induced SNR: 9.00415739891695
# SD(Y):  3.1162676627236974
# Naive Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 450 th simulation done
# seed: 1450
# Equally spaced quantile knots used.
# Main: 1.3945577895737624
# Interaction: 1.836239256286161
# induced SNR: 8.124191097293398
# SD(Y):  2.9140785619150398
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 1 451 th simulation done
# seed: 1451
# Equally spaced quantile knots used.
# Main: 1.2949427879001056
# Interaction: 1.8733075583432899
# induced SNR: 8.150321440232757
# SD(Y):  3.111975486342197
# Naive Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 452 th simulation done
# seed: 1452
# Equally spaced quantile knots used.
# Main: 1.3968397971965347
# Interaction: 1.7805022013397924
# induced SNR: 7.787410815993403
# SD(Y):  2.940557008655639
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 1 453 th simulation done
# seed: 1453
# Equally spaced quantile knots used.
# Main: 1.5099791637583833
# Interaction: 1.7077130509255327
# induced SNR: 8.224225265476072
# SD(Y):  3.0940345958052995
# Naive Selected Groups: 12
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 454 th simulation done
# seed: 1454
# Equally spaced quantile knots used.
# Main: 1.3793073859697196
# Interaction: 1.8842060396248723
# induced SNR: 8.429580577949388
# SD(Y):  3.1228693453260794
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 455 th simulation done
# seed: 1455
# Equally spaced quantile knots used.
# Main: 1.3402285748858889
# Interaction: 1.8102703254844719
# induced SNR: 7.7897287277818075
# SD(Y):  2.8736883892837324
# Naive Selected Groups: 10
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 456 th simulation done
# seed: 1456
# Equally spaced quantile knots used.
# Main: 1.3705595290033878
# Interaction: 1.684404951360763
# induced SNR: 7.06524879842728
# SD(Y):  2.8519631011574353
# Naive Selected Groups: 8
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 1 457 th simulation done
# seed: 1457
# Equally spaced quantile knots used.
# Main: 1.5199090880270067
# Interaction: 1.8246555984381108
# induced SNR: 9.077995997652481
# SD(Y):  3.181713195798954
# Naive Selected Groups: 9
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 1 458 th simulation done
# seed: 1458
# Equally spaced quantile knots used.
# Main: 1.46678353338977
# Interaction: 1.9084104619693747
# induced SNR: 8.627376067665402
# SD(Y):  3.0382348003109776
# Naive Selected Groups: 13
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 1 459 th simulation done
# seed: 1459
# Equally spaced quantile knots used.
# Main: 1.4104253709331203
# Interaction: 1.879059921947779
# induced SNR: 8.244135733803722
# SD(Y):  3.0080548102960005
# Naive Selected Groups: 9
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 460 th simulation done
# seed: 1460
# Equally spaced quantile knots used.
# Main: 1.4065174583003268
# Interaction: 1.888084703981106
# induced SNR: 8.256042395475584
# SD(Y):  3.0798386314011093
# Naive Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 12
# 1 461 th simulation done
# seed: 1461
# Equally spaced quantile knots used.
# Main: 1.4856000825142441
# Interaction: 1.773502612940851
# induced SNR: 8.600116465329455
# SD(Y):  3.1187961868459007
# Naive Selected Groups: 9
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 462 th simulation done
# seed: 1462
# Equally spaced quantile knots used.
# Main: 1.4082993893153704
# Interaction: 1.8602905232309104
# induced SNR: 8.539547622694377
# SD(Y):  2.952678324391938
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 463 th simulation done
# seed: 1463
# Equally spaced quantile knots used.
# Main: 1.3172533086512594
# Interaction: 1.7713699831682896
# induced SNR: 7.4849115847201375
# SD(Y):  2.9106968831957025
# Naive Selected Groups: 9
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 464 th simulation done
# seed: 1464
# Equally spaced quantile knots used.
# Main: 1.3903391680723487
# Interaction: 1.9054385623550094
# induced SNR: 8.74936212645549
# SD(Y):  3.1101418224485737
# Naive Selected Groups: 12
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 465 th simulation done
# seed: 1465
# Equally spaced quantile knots used.
# Main: 1.3772964651746378
# Interaction: 1.924810206544254
# induced SNR: 8.970563620915506
# SD(Y):  3.077785246192811
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 466 th simulation done
# seed: 1466
# Equally spaced quantile knots used.
# Main: 1.4239607294558523
# Interaction: 1.8665532441941795
# induced SNR: 8.570655029991558
# SD(Y):  3.1385137320262415
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 12
# 1 467 th simulation done
# seed: 1467
# Equally spaced quantile knots used.
# Main: 1.4484054672958884
# Interaction: 1.837195150512976
# induced SNR: 8.674231831093314
# SD(Y):  3.1232775589823363
# Naive Selected Groups: 8
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 468 th simulation done
# seed: 1468
# Equally spaced quantile knots used.
# Main: 1.5190571585250379
# Interaction: 1.8686957115559863
# induced SNR: 9.38094096588472
# SD(Y):  3.2800206560433893
# Naive Selected Groups: 11
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 13
# 1 469 th simulation done
# seed: 1469
# Equally spaced quantile knots used.
# Main: 1.456045359650843
# Interaction: 1.895876144250271
# induced SNR: 9.196085657484437
# SD(Y):  3.178651086723695
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 470 th simulation done
# seed: 1470
# Equally spaced quantile knots used.
# Main: 1.3332340720572642
# Interaction: 1.914141483806662
# induced SNR: 8.164704442604387
# SD(Y):  2.9694816236214656
# Naive Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 471 th simulation done
# seed: 1471
# Equally spaced quantile knots used.
# Main: 1.3322376303142107
# Interaction: 1.8043323294134093
# induced SNR: 7.745568243552365
# SD(Y):  2.9552453890904706
# Naive Selected Groups: 8
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 472 th simulation done
# seed: 1472
# Equally spaced quantile knots used.
# Main: 1.3813630197359705
# Interaction: 1.7208313371643689
# induced SNR: 7.540211452068942
# SD(Y):  2.9251387437939504
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 473 th simulation done
# seed: 1473
# Equally spaced quantile knots used.
# Main: 1.374508840637754
# Interaction: 1.8784434799047176
# induced SNR: 8.709315500178874
# SD(Y):  3.1711393016992564
# Naive Selected Groups: 13
# Data Carving Randomization Used
# MLE Selected Groups: 16
# 1 474 th simulation done
# seed: 1474
# Equally spaced quantile knots used.
# Main: 1.412480878147282
# Interaction: 1.8047427913040355
# induced SNR: 8.350779798669636
# SD(Y):  3.206712555905443
# Naive Selected Groups: 14
# Data Carving Randomization Used
# MLE Selected Groups: 13
# 1 475 th simulation done
# seed: 1475
# Equally spaced quantile knots used.
# Main: 1.2344125136754482
# Interaction: 1.7710890027676922
# induced SNR: 7.146722601473924
# SD(Y):  2.8555343879062445
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 1 476 th simulation done
# seed: 1476
# Equally spaced quantile knots used.
# Main: 1.3804879285331682
# Interaction: 1.6718838485286511
# induced SNR: 7.374813454803568
# SD(Y):  2.964436610632636
# Naive Selected Groups: 10
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 1 477 th simulation done
# seed: 1477
# Equally spaced quantile knots used.
# Main: 1.3802696893499595
# Interaction: 1.7145587827205855
# induced SNR: 7.609296053622829
# SD(Y):  2.8994165122506717
# Naive Selected Groups: 10
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 478 th simulation done
# seed: 1478
# Equally spaced quantile knots used.
# Main: 1.349263413437949
# Interaction: 1.7959899792948393
# induced SNR: 7.755397669268284
# SD(Y):  3.0020732880954952
# Naive Selected Groups: 8
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 1 479 th simulation done
# seed: 1479
# Equally spaced quantile knots used.
# Main: 1.423248356341307
# Interaction: 1.8570683529644223
# induced SNR: 8.830077899653903
# SD(Y):  3.110071016183959
# Naive Selected Groups: 12
# Data Carving Randomization Used
# MLE Selected Groups: 13
# 1 480 th simulation done
# seed: 1480
# Equally spaced quantile knots used.
# Main: 1.4539936012263235
# Interaction: 1.8729793825841836
# induced SNR: 9.02826297393948
# SD(Y):  3.052550941445748
# Naive Selected Groups: 9
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 481 th simulation done
# seed: 1481
# Equally spaced quantile knots used.
# Main: 1.4006574688444278
# Interaction: 1.8623722745882696
# induced SNR: 8.559630389491103
# SD(Y):  3.0347609729328484
# Naive Selected Groups: 8
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 482 th simulation done
# seed: 1482
# Equally spaced quantile knots used.
# Main: 1.473658124234288
# Interaction: 1.7547099198568339
# induced SNR: 8.07619979792167
# SD(Y):  3.0751339843507943
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 483 th simulation done
# seed: 1483
# Equally spaced quantile knots used.
# Main: 1.3925762880628594
# Interaction: 1.829153224368194
# induced SNR: 8.155861029640223
# SD(Y):  2.9898522101569656
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 484 th simulation done
# seed: 1484
# Equally spaced quantile knots used.
# Main: 1.3762656552192103
# Interaction: 1.6849336668997668
# induced SNR: 7.412805725767936
# SD(Y):  2.8585870012898247
# Naive Selected Groups: 12
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 485 th simulation done
# seed: 1485
# Equally spaced quantile knots used.
# Main: 1.3659909053568262
# Interaction: 1.8111352632143694
# induced SNR: 8.36998494164637
# SD(Y):  3.069990749921458
# Naive Selected Groups: 12
# Data Carving Randomization Used
# MLE Selected Groups: 12
# 1 486 th simulation done
# seed: 1486
# Equally spaced quantile knots used.
# Main: 1.4496391767787775
# Interaction: 1.875219485930742
# induced SNR: 8.784005101643157
# SD(Y):  3.111152736518399
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 487 th simulation done
# seed: 1487
# Equally spaced quantile knots used.
# Main: 1.418067364179534
# Interaction: 1.7849844088956703
# induced SNR: 8.230663262920606
# SD(Y):  2.9556814694520073
# Naive Selected Groups: 8
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 488 th simulation done
# seed: 1488
# Equally spaced quantile knots used.
# Main: 1.2836729660348078
# Interaction: 1.8873925542950079
# induced SNR: 7.782730111983985
# SD(Y):  3.0072655021103576
# Naive Selected Groups: 14
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 489 th simulation done
# seed: 1489
# Equally spaced quantile knots used.
# Main: 1.4736396947944015
# Interaction: 2.044798717480707
# induced SNR: 9.959199888522411
# SD(Y):  3.296375371188829
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 490 th simulation done
# seed: 1490
# Equally spaced quantile knots used.
# Main: 1.43453503441295
# Interaction: 1.8060756741608406
# induced SNR: 8.377088861981877
# SD(Y):  2.9994756458252865
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 491 th simulation done
# seed: 1491
# Equally spaced quantile knots used.
# Main: 1.4047953285220751
# Interaction: 1.791846557776163
# induced SNR: 8.008422636692828
# SD(Y):  2.951700797124898
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 492 th simulation done
# seed: 1492
# Equally spaced quantile knots used.
# Main: 1.4103443268925324
# Interaction: 1.8698527054970193
# induced SNR: 8.74984795033383
# SD(Y):  3.023372250624699
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 1 493 th simulation done
# seed: 1493
# Equally spaced quantile knots used.
# Main: 1.3806424412699225
# Interaction: 1.7563473575162405
# induced SNR: 7.5488631928585725
# SD(Y):  2.929160365729325
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 1 494 th simulation done
# seed: 1494
# Equally spaced quantile knots used.
# Main: 1.4784305586335638
# Interaction: 1.8249227230524363
# induced SNR: 8.812582819010581
# SD(Y):  3.122952499118086
# Naive Selected Groups: 12
# Data Carving Randomization Used
# MLE Selected Groups: 12
# 1 495 th simulation done
# seed: 1495
# Equally spaced quantile knots used.
# Main: 1.4093967175033033
# Interaction: 1.67645394762295
# induced SNR: 7.686974990738602
# SD(Y):  3.010458296890225
# Naive Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 12
# 1 496 th simulation done
# seed: 1496
# Equally spaced quantile knots used.
# Main: 1.3589707252886543
# Interaction: 1.830644285285562
# induced SNR: 8.072120097717132
# SD(Y):  2.9678853206652485
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 497 th simulation done
# seed: 1497
# Equally spaced quantile knots used.
# Main: 1.33036742551031
# Interaction: 1.8173836544626238
# induced SNR: 7.828771667141037
# SD(Y):  3.0615349133756182
# Naive Selected Groups: 8
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 1 498 th simulation done
# seed: 1498
# Equally spaced quantile knots used.
# Main: 1.3180861860477884
# Interaction: 1.9179498348630561
# induced SNR: 8.474829738649309
# SD(Y):  3.101362043070486
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 13
# 1 499 th simulation done
# seed: 1499
# Equally spaced quantile knots used.
# Main: 1.4229814499849787
# Interaction: 1.8189918742009283
# induced SNR: 8.651832903484912
# SD(Y):  3.2553092300354898
# Naive Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 9

# %%
import joblib
joblib.dump([ds_rank_def_count, target_dict, pval_dict, MSE_dict, oper_char],
            f'vary_signal_{prop}.pkl', compress=1)
# Out:
# ['vary_signal_0.9.pkl']

# %%
import joblib
ds_rank_def_count, target_dict, pval_dict, MSE_dict, oper_char = joblib.load('vary_signal.pkl')

# %%
ds_rank_def_count
# Out:
# {8: 0, 4: 0, 2: 0, 1: 0}

# %%
#ds_rank_def_count, target_dict, pval_dict, MSE_dict, oper_char = joblib.load('toy_weak.pkl')

# %%
ds_rank_def_count
# Out:
# {8: 0, 4: 0, 2: 0, 1: 0}

# %%
plot_ecdfs(pval_dict, xaxis="Main Signal")

# %%
## Plotting dict: SNR - Method - List of pvals
## Plotting dict: SNR - Method - List of pvals
filtered_dict = filter_pval_dict_new(target_dict, threshold = 0,
                                     operator=ge)

# %%
plot_ecdfs(filtered_dict, xaxis="SD(Y)")

# %%
my_palette = {"MLE": "#48c072",
                  "Naive": "#fc5a50",
                  "Data Splitting": "#03719c"}
sns.set_style("white", {'axes.facecolor': 'white',
                            'axes.grid': True,
                            'axes.linewidth': 2.0,
                            'grid.linestyle': u'--',
                            'grid.linewidth': 4.0,
                            'xtick.major.size': 5.0,
                            })

# %%
sns.pointplot(x=pd.DataFrame(oper_char)["sd_y"],
              y=pd.DataFrame(oper_char)["avg length"],
              hue=pd.DataFrame(oper_char)["method"], markers='o',
              palette=my_palette)
#plt.ylim(10, 30)
plt.xlabel("Main Signal")
plt.ylabel("Average Length")
# Out:
# Text(0, 0.5, 'Average Length')

# %%
sns.pointplot(x=pd.DataFrame(MSE_dict)["sd_y"],
              y=pd.DataFrame(MSE_dict)["MSE"],
              hue=pd.DataFrame(MSE_dict)["method"], markers='o',
              palette=my_palette)
#plt.ylim(26.5,30)
plt.xlabel("Main signal")
plt.ylabel("Test MSE")
# Out:
# Text(0, 0.5, 'Test MSE')

# %% [markdown]
# # Applying BY Correction to the p-values

# %%
from collections import defaultdict
from scipy.stats import false_discovery_control


def add_BY_pval_by_method_and_index(data):
    # Check if BYpval is there
    if "BYpval" in data.keys():
        return
    # Assuming your dictionary is named 'data' and structured as described
    methods = data['method']
    indices = data['index']
    pvals = data['pval']

    # Initialize default dictionaries to collect p-values and positions for each (method, index) pair
    pvals_dict = defaultdict(list)
    pos_dict = defaultdict(list)

    # Iterate over the data and populate the dictionaries
    for i, (method, index, pval) in enumerate(zip(methods, indices, pvals)):
        key = (method, index)
        pvals_dict[key].append(pval)
        pos_dict[key].append(i)

    # Initialize BYpvals array with the same length as pvals
    BYpvals = [0] * len(pvals)  # or use numpy.zeros_like(pvals) if pvals is a numpy array

    # Apply BY correction and assign back to positions
    for key in pvals_dict:
        pvals_list = pvals_dict[key]
        positions = pos_dict[key]
        corrected_pvals = false_discovery_control(pvals_list, method='by')
        for pos, by_pval in zip(positions, corrected_pvals):
            BYpvals[pos] = by_pval

    # Add BYpvals to the original data dictionary
    data['BYpvals'] = BYpvals

    # Now, pvals_dict contains lists of p-values for each unique (method, index) pair

# %%
add_BY_pval_by_method_and_index(target_dict)

# %% [markdown]
# # Calculating Thresholded Power

# %%
def calculate_thresholded_power(pvalue, targets, level, threshold=0.05,
                                operator=ge):
    pvalue = np.array(pvalue)
    targets = np.array(targets)
    non_null = operator(np.abs(targets), threshold)
    rejection = pvalue < level
    if np.sum(non_null) == 0:
        return 0
    else:
        true_rej = np.sum(non_null * rejection) / np.sum(non_null)

    return true_rej

def calculate_thresholded_power_df(targets_dict,
                                   threshold=0.1,
                                   level=0.1,
                                   operator=ge, 
                                   pval_key = "BYpvals"):
    grouped_targets = pd.DataFrame(targets_dict).groupby(['index',
                                                          'method', 'parameter'])
    power_df = {}
    power_df['parameter'] = []
    power_df['method'] = []
    power_df['thresholded power'] = []
    for name, group in grouped_targets:
        power_df['parameter'].append(name[2])
        power_df['method'].append(name[1])
        pvalues = group[pval_key]
        targets = group['target']
        power_df['thresholded power'].append(
            calculate_thresholded_power(pvalues, targets, level=level, 
                                        threshold=threshold, operator=operator))
    return power_df

# %%
def point_plot_power(oper_char_dfs, x_axis='p', hue='method', 
                     ylim_low=None, ylim_high=None, exclude_naive=True,
                     randomizer_scales=None, x_label=None):
    for i in range(len(oper_char_dfs)):
        oper_char_dfs[i] = oper_char_dfs[i].copy()
        if exclude_naive:
            oper_char_dfs[i] = oper_char_dfs[i][oper_char_dfs[i]['method'] != "Naive"]
    sns.set_style("white", {'axes.facecolor': 'white',
                            'axes.grid': True,
                            'axes.linewidth': 2.0,
                            'grid.linestyle': u'--',
                            'grid.linewidth': 4.0,
                            'xtick.major.size': 5.0,
                            })
    # sns.histplot(oper_char_df["sparsity size"])
    # plt.show()
    n_subplots = len(oper_char_dfs)
    # cols = int(np.ceil(n_subplots / 2))
    cols = n_subplots

    fig = plt.figure(figsize=(cols * 5, 6))

    my_palette = {"MLE": "#48c072",
                  "Naive": "#fc5a50",
                  "Data Splitting": "#03719c"}

    # Create each subplot
    for i in range(1, n_subplots + 1):
        # ax = fig.add_subplot(2, cols, i) #two rows
        ax = fig.add_subplot(1, cols, i)  # one row
        if hue is not None:
            sns.pointplot(x=oper_char_dfs[i-1][x_axis],
                          y=oper_char_dfs[i-1]['thresholded power'],
                          hue=oper_char_dfs[i-1][hue],
                          markers='o',
                          palette=my_palette,
                          ax=ax)
            ax.set_title("Randomizer Scale:" + str(randomizer_scales[i-1]))
        else:
            sns.pointplot(x=oper_char_dfs[i-1][x_axis],
                          y=oper_char_dfs[i-1]['thresholded power'],
                          markers='o',
                          palette=my_palette,
                          ax=ax)
        if ylim_low is not None and ylim_high is not None:
            ax.set_ylim([ylim_low, ylim_high])

        ax.legend().set_visible(False)

    handles, labels = ax.get_legend_handles_labels()
    # fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.2)

    fig.subplots_adjust(bottom=0.3)
    fig.legend(handles, labels, loc='lower center', ncol=n_subplots,
               prop={'size': 15})

    # cov_plot.legend_.remove()
    # len_plot.legend_.remove()

    # plt.suptitle("Changing n,p")
    plt.subplots_adjust(wspace=0.3, hspace=0.5)
    if x_label is not None:
        plt.xlabel(x_label)
    plt.show()

# %%
power_threshold = 1
power_df1 = calculate_thresholded_power_df(targets_dict=target_dict, 
                                           threshold=power_threshold, level=0.1,
                                           operator=ge, pval_key="BYpvals")

# %%
point_plot_power(oper_char_dfs=[pd.DataFrame(power_df1)],
                 x_axis="parameter",
                 hue="method", ylim_high=0.6, ylim_low=0,
                 randomizer_scales=["Hessian"], exclude_naive=False,
                 x_label="Split ratio (r)")

# %%
my_palette = {"MLE": "#48c072",
                  "Naive": "#fc5a50",
                  "Data Splitting": "#03719c"}

# %%
df = pd.DataFrame(power_df1)
#df = df[df["method"] != "Naive"]
sns.pointplot(x=df["parameter"],
              y=df["thresholded power"],
              hue=df["method"], markers='o',
              palette=my_palette)
plt.xlabel("Split ratio (r)")
plt.ylabel("Thresholded Power")
# Out:
# Text(0, 0.5, 'Thresholded Power')

# %%
power_threshold = 1
FDP_df1 = calculate_thresholded_power_df(targets_dict=target_dict, 
                                           threshold=power_threshold, level=0.1,
                                           operator=le, pval_key="BYpvals")

# %%
df = pd.DataFrame(FDP_df1)
#df = df[df["method"] != "Naive"]
sns.pointplot(x=df["parameter"],
              y=df["thresholded power"],
              hue=df["method"], markers='o',
              palette=my_palette)
plt.xlabel("Split ratio (r)")
plt.ylabel("FDP")
# Out:
# Text(0, 0.5, 'FDP')
