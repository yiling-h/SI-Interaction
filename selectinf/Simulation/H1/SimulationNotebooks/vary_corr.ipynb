# %%
import time, sys

import numpy as np
import pandas as pd

sys.path.append('/home/yilingh/SI-Interaction')

from selectinf.Simulation.H1.nonlinear_H1_helpers import *

# %%
from operator import le, ge
def filter_pval_dict_new(target_dict, threshold=0.05, operator=le, p_flag="pivot"):
    grouped_targets = pd.DataFrame(target_dict).groupby(['parameter', 'method'])
    filtered_dict = {}
    # Filter by 
    for name, group in grouped_targets:
        # Subset the selected targets
        selected_targets_id = operator(np.abs(group['target']), threshold)
        selected_targets = group[p_flag][selected_targets_id]
        # Then filtered_dict.keys must be a dictionary
        if name[0] in filtered_dict.keys():
            filtered_dict[name[0]][name[1]] = selected_targets.tolist()
        else:
            filtered_dict[name[0]] = {}
            filtered_dict[name[0]][name[1]] = selected_targets.tolist()
        
    return filtered_dict
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_MSE(oper_char):
    specific_method = "MLE"  # Replace with the name of your method
    
    # Create a modified DataFrame
    df_modified = oper_char.copy()
    
    # For the specific method, keep "tau" values separate
    # For other methods, set "tau" to a single category, e.g., "All"
    df_modified['prop'] = df_modified.apply(
        lambda row: row['prop'] if row['method'] == specific_method else 'Naive/DS', axis=1
    )
    
    # Plotting
    sns.boxplot(x='method', y='MSE', hue='prop', data=df_modified, showmeans=True)
    plt.xlabel("Method")
    plt.ylabel("MSE")
    plt.title("Boxplot of MSE by Method and prop")
    plt.show()

# %% [markdown]
# # Simulation: vary correlation between features

# %%
def predict(beta_hat, X_test):
    return X_test.dot(beta_hat)

def generate_test(Y_mean, noise_sd):
    n = Y_mean.shape[0]
    Y_test = Y_mean + np.random.normal(size=(n,), scale=noise_sd)
    
    return Y_test

# %%
# A dictionary recording simulation results and metrics
oper_char = {}
oper_char["coverage rate"] = []
oper_char["avg length"] = []
oper_char["method"] = []
#oper_char["MSE"] = []
oper_char["prop"] = []
oper_char["rho"] = []
oper_char["signal"] = []
oper_char["main signal"] = []
oper_char["target"] = []
oper_char["power"] = []

MSE_dict = {}
MSE_dict["MSE"] = []
MSE_dict["method"] = []
MSE_dict["rho"] = []

# Dictionary of projected targets, over all simulation parameters
target_dict = {}
target_dict["parameter"] = []
target_dict["target"] = []
target_dict["target id"] = []
target_dict["method"] = []
target_dict["index"] = []
target_dict["pivot"] = []
target_dict["pval"] = []

# A dictionary recording p-values for each true interaction
# over all simulation results.
# Each simulation parameter (here parameter_list contain a list of main signal strengths 
# to be considered) has a corresponding dictionary of results
parameter_list = np.array([0, 0.2, 0.4, 0.6])
pval_dict = {}
for x in parameter_list:
    pval_dict[x] = {}
    for m in ['Naive', 'Data Splitting', 'MLE']:
        pval_dict[x][m] = []

# Group lasso solver constructor
const = group_lasso.gaussian
active_inter_list_true = np.array([[0,1], [1,2], [2,4], [1,5], [2,6]])
active_inter_list_true_list = [(x[0],x[1]) for x in active_inter_list_true]

#p = 50
#rho = 0.5 # Correlation of signal covariates (amongst themselves), and noise.
sig = 2  # Controlling interaction vs main signals. 
           # Setting it this way generates comparable main 
           # and interaction signals (sig = 2 works )
weights = 0.05 # Group Lasso weights
s_inter = 5 # Number of true interactions
p_nl = 20 # Number of nonlinear covariates
n=200
root_n_scaled = False
main_sig = 2
prop=0.9

ds_rank_def_count = {corr: 0 for corr in parameter_list}

for rho in parameter_list:
    for i in range(200):
        np.random.seed(i+1000)
        #MSE_set = False
        
        print(rho, i,"th simulation done")
        print("seed:", i+1000)
        # Generating a (X, Y) pair, and corresponding basis expansion
        # The 'weakhierarchy' argument is overridden by setting 
        # `active_inter_list`.
        (design, data_interaction, Y, Y_mean, data_combined,
         groups, active, active_inter_adj, active_inter_list, gamma) \
            = (generate_gaussian_instance_nonlinear_interaction_simple
               (n=n, p_nl=p_nl, rho=rho, full_corr=False,
                rho_noise=rho, block_corr=True, rho_cross=rho*0.8,
                SNR = None, main_signal=main_sig, noise_sd=5,
                nknots = 6, degree = 2, interaction_signal=sig,
                random_signs=False, scale=root_n_scaled, center=False,
                structure='weakhierarchy', s_interaction=s_inter,
                intercept=True, active_inter_list=active_inter_list_true, 
                return_gamma=True))
        print("SD(Y): ", np.std(Y))
        Y_test = Y_mean + np.random.normal(size=(n,), scale=5)
        
        # Performing Naive inference using 'all pairs'
        (coverages, lengths, selected_inter, p_values, pivots, targets, idx, 
        beta_hat_naive) \
            = naive_inference_inter(X=design, Y=Y, groups=groups,
                                    Y_mean=Y_mean, const=const,
                                    n_features=20, interactions=data_interaction,
                                    weight_frac=weights, level=0.9, mode='weakhierarchy',
                                    solve_only=False, continued=False,
                                    parallel=False, p_val=True, 
                                    return_pivot=True, intercept=True, 
                                    target_ids=active_inter_list_true_list,
                                       root_n_scaled=root_n_scaled)
        
        noselection_naive = coverages is None
        
        if not noselection_naive:
            # Naive
            oper_char["coverage rate"].append(np.mean(coverages))
            oper_char["avg length"].append(np.mean(lengths))
            oper_char["method"].append('Naive')
            oper_char["signal"].append(sig)
            oper_char["main signal"].append(main_sig)
            oper_char["prop"].append(prop)
            oper_char["rho"].append(rho)
            #oper_char["MSE"].append(MSE_naive)
            #oper_char["SNR"].append(SNR)
            oper_char["target"].append(targets[0])
            pval_dict[rho]['Naive'] += (p_values)
            oper_char["power"].append(calculate_power(p_values, targets, 0.1))
            update_targets(dict=target_dict,
                           true_inter_list=active_inter_list_true_list,
                           targets=targets, parameter=rho,
                           method="Naive", idx=idx,
                           pvals=p_values,
                           pivots=pivots, sim_idx=i)
          
        # Continue if Naive yields a nonempty group lasso selection
        # (this is almost always the case)
        # Performing data splitting using 'all pairs'
        # DS solve only
        ds_rank_def = False
        (nonzero_ds, selected_groups_ds, subset_select_ds, beta_hat_ds) \
            = data_splitting_inter(X=design, Y=Y, groups=groups,
                                   Y_mean=Y_mean, const=const,
                                   n_features=20, interactions=data_interaction,
                                   proportion=prop,
                                   weight_frac=weights, level=0.9,
                                   mode='weakhierarchy',
                                   solve_only=True, continued=False,
                                   parallel=False, p_val=True,
                                   target_ids=active_inter_list_true_list,
                                   root_n_scaled=root_n_scaled)
        if nonzero_ds.sum() + 1 >= n-subset_select_ds.sum():
            ds_rank_def = True
            ds_rank_def_count[rho] += 1

        if not ds_rank_def:
            (coverages_ds, lengths_ds, selected_inter_ds,
             p_values_ds, pivots_ds, targets_ds, idx_ds, beta_hat_ds) \
                = data_splitting_inter(X=design, Y=Y, groups=groups,
                                       Y_mean=Y_mean, const=const,
                                       n_features=20, interactions=data_interaction,
                                       proportion=prop,
                                       weight_frac=weights, level=0.9,
                                       mode='weakhierarchy',
                                       solve_only=False, continued=True,
                                       parallel=False, p_val=True,
                                       target_ids=active_inter_list_true_list,
                                       root_n_scaled=root_n_scaled,
                                       subset_cont=subset_select_ds,
                                       nonzero_cont=nonzero_ds,
                                       selected_groups_cont=selected_groups_ds,
                                       soln_cont=beta_hat_ds)
            noselection_ds = coverages_ds is None
        
        if not noselection_ds:
            # Data splitting
            oper_char["coverage rate"].append(np.mean(coverages_ds))
            oper_char["avg length"].append(np.mean(lengths_ds))
            oper_char["method"].append('Data Splitting')
            oper_char["signal"].append(sig)
            oper_char["main signal"].append(main_sig)
            oper_char["prop"].append(prop)
            oper_char["rho"].append(rho)
            #oper_char["MSE"].append(MSE_ds)
            #oper_char["SNR"].append(SNR)
            oper_char["target"].append(targets_ds[0])
            pval_dict[rho]['Data Splitting'] += (p_values_ds)
            oper_char["power"].append(calculate_power(p_values_ds, targets_ds, 0.1))
            update_targets(dict=target_dict,
                           true_inter_list=active_inter_list_true_list,
                           targets=targets_ds, parameter=rho,
                           method="Data Splitting", idx=idx_ds,
                               pvals=p_values_ds,
                               pivots=pivots_ds, sim_idx=i)
        
        # Continue if data splitting yields a nonempty group lasso selection
        # (this is almost always the case)    
        # Performing MLE using 'all pairs'
        (coverages_MLE, lengths_MLE, selected_inter_MLE, p_values_MLE, 
         pivots_MLE, targets_MLE, idx_MLE, beta_hat_MLE)\
            = (MLE_inference_inter
               (X=design, Y=Y, Y_mean=Y_mean, groups=groups,
                n_features=p_nl, interactions=data_interaction,
                intercept=True, 
                #randomizer_sd_const=tau, 
                proportion=prop,
                weight_frac=weights,
                level=0.9, mode='weakhierarchy', solve_only=False, 
                continued=False, parallel=False, p_val=True, 
                target_ids=active_inter_list_true_list,
                root_n_scaled=root_n_scaled))
        noselection_MLE = coverages_MLE is None
        
        # Collect results if all three methods yields 
        # nonempty first-stage selection
        if not noselection_MLE:
            # MLE
            oper_char["coverage rate"].append(np.mean(coverages_MLE))
            oper_char["avg length"].append(np.mean(lengths_MLE))
            oper_char["method"].append('MLE')
            oper_char["signal"].append(sig)
            oper_char["main signal"].append(main_sig)
            oper_char["prop"].append(prop)
            oper_char["rho"].append(rho)
            #oper_char["MSE"].append(MSE_MLE)
            #oper_char["SNR"].append(SNR)
            oper_char["target"].append(targets_MLE[0])
            pval_dict[rho]['MLE'] += (p_values_MLE)
            oper_char["power"].append(calculate_power(p_values_MLE, 
                                                      targets_MLE,
                                                      0.1))
            update_targets(dict=target_dict,
                           true_inter_list=active_inter_list_true_list,
                           targets=targets_MLE, parameter=rho,
                           method="MLE", idx=idx_MLE,
                               pvals=p_values_MLE,
                               pivots=pivots_MLE, sim_idx=i)
        
        # Set MSE  
        MSE_naive = np.mean((Y_test - predict(beta_hat_naive, design))**2)
        MSE_dict["MSE"].append(MSE_naive)
        MSE_dict["method"].append("Naive")
        MSE_dict["rho"].append(rho)
        
        MSE_ds = np.mean((Y_test - predict(beta_hat_ds, design))**2)
        MSE_dict["MSE"].append(MSE_ds)
        MSE_dict["method"].append("Data Splitting")
        MSE_dict["rho"].append(rho)
        
        MSE_MLE = np.mean((Y_test - predict(beta_hat_MLE, design))**2)
        MSE_dict["MSE"].append(MSE_MLE)
        MSE_dict["method"].append("MLE")
        MSE_dict["rho"].append(rho)
        MSE_set = True
# Out:
# 0.0 0 th simulation done
# seed: 1000
# Equally spaced quantile knots used.
# Main: 1.3662547409870052
# Interaction: 1.4765438701279432
# induced SNR: 0.19398538293409823
# SD(Y):  5.450218965272626
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 1 th simulation done
# seed: 1001
# Equally spaced quantile knots used.
# Main: 1.4057006496031679
# Interaction: 1.2313233787541145
# induced SNR: 0.1703823266213858
# SD(Y):  4.997691381232863
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 2 th simulation done
# seed: 1002
# Equally spaced quantile knots used.
# Main: 1.342114632717915
# Interaction: 1.3209632315464137
# induced SNR: 0.17797838478380346
# SD(Y):  5.328974076405815
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 3 th simulation done
# seed: 1003
# Equally spaced quantile knots used.
# Main: 1.5254798728374608
# Interaction: 1.3767684165440197
# induced SNR: 0.20014472567520336
# SD(Y):  5.603733723565852
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 4 th simulation done
# seed: 1004
# Equally spaced quantile knots used.
# Main: 1.3045200388035822
# Interaction: 1.3652859489960132
# induced SNR: 0.17256763999508148
# SD(Y):  5.348378606622036
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 5 th simulation done
# seed: 1005
# Equally spaced quantile knots used.
# Main: 1.4895774863331261
# Interaction: 1.3446195686123223
# induced SNR: 0.20550834410197835
# SD(Y):  5.318442660915106
# Naive Selected Groups: 6
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 6 th simulation done
# seed: 1006
# Equally spaced quantile knots used.
# Main: 1.521412925010049
# Interaction: 1.4573117925911059
# induced SNR: 0.2221429422547266
# SD(Y):  5.374177028200406
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 7 th simulation done
# seed: 1007
# Equally spaced quantile knots used.
# Main: 1.433226521455621
# Interaction: 1.3665492761694578
# induced SNR: 0.2003788627242825
# SD(Y):  4.906097460692196
# Naive Selected Groups: 5
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 8 th simulation done
# seed: 1008
# Equally spaced quantile knots used.
# Main: 1.3274700620778221
# Interaction: 1.4369738045900682
# induced SNR: 0.19423718345608793
# SD(Y):  5.212779303926434
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 9 th simulation done
# seed: 1009
# Equally spaced quantile knots used.
# Main: 1.394917719708576
# Interaction: 1.457862465681244
# induced SNR: 0.21568984721106296
# SD(Y):  5.549779645879785
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 10 th simulation done
# seed: 1010
# Equally spaced quantile knots used.
# Main: 1.3812480509557126
# Interaction: 1.3852511102076295
# induced SNR: 0.18830727008789064
# SD(Y):  5.516665218120391
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 11 th simulation done
# seed: 1011
# Equally spaced quantile knots used.
# Main: 1.3634711712770713
# Interaction: 1.318716660853349
# induced SNR: 0.16959948370671785
# SD(Y):  5.242382850065888
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 12 th simulation done
# seed: 1012
# Equally spaced quantile knots used.
# Main: 1.2820841387538315
# Interaction: 1.4896967198912547
# induced SNR: 0.19799686682249903
# SD(Y):  5.573132184360811
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 13 th simulation done
# seed: 1013
# Equally spaced quantile knots used.
# Main: 1.4026248546802156
# Interaction: 1.3975177568318689
# induced SNR: 0.20236927390479215
# SD(Y):  5.4828238999111045
# Naive Selected Groups: 6
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 14 th simulation done
# seed: 1014
# Equally spaced quantile knots used.
# Main: 1.4983484752742422
# Interaction: 1.4163841330460158
# induced SNR: 0.2029455299190395
# SD(Y):  5.286884622313878
# Naive Selected Groups: 5
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 15 th simulation done
# seed: 1015
# Equally spaced quantile knots used.
# Main: 1.3852733499273187
# Interaction: 1.4589979948432021
# induced SNR: 0.20552819778303086
# SD(Y):  5.317837590778443
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 16 th simulation done
# seed: 1016
# Equally spaced quantile knots used.
# Main: 1.5278193553785573
# Interaction: 1.339844950396663
# induced SNR: 0.22622062784701663
# SD(Y):  5.912257790862276
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 17 th simulation done
# seed: 1017
# Equally spaced quantile knots used.
# Main: 1.422021021396718
# Interaction: 1.4644653829222865
# induced SNR: 0.21556378247147642
# SD(Y):  5.448824768300039
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 18 th simulation done
# seed: 1018
# Equally spaced quantile knots used.
# Main: 1.3914769455536307
# Interaction: 1.4621822183130588
# induced SNR: 0.20987738535040615
# SD(Y):  5.459151769348031
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 19 th simulation done
# seed: 1019
# Equally spaced quantile knots used.
# Main: 1.5141943180359065
# Interaction: 1.3822697823067736
# induced SNR: 0.23446199162744347
# SD(Y):  5.110975366026457
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 20 th simulation done
# seed: 1020
# Equally spaced quantile knots used.
# Main: 1.4478159166185414
# Interaction: 1.4762405933470748
# induced SNR: 0.2286737891181492
# SD(Y):  5.8494570380767135
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 21 th simulation done
# seed: 1021
# Equally spaced quantile knots used.
# Main: 1.2595291763743577
# Interaction: 1.3756886323261452
# induced SNR: 0.1566328160849498
# SD(Y):  5.5229307349006165
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 22 th simulation done
# seed: 1022
# Equally spaced quantile knots used.
# Main: 1.4121950654441213
# Interaction: 1.4434537036392594
# induced SNR: 0.21226203117555045
# SD(Y):  5.7536968169866824
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 23 th simulation done
# seed: 1023
# Equally spaced quantile knots used.
# Main: 1.5146226783275378
# Interaction: 1.4430027696075645
# induced SNR: 0.2314579986220735
# SD(Y):  5.322400483787933
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 24 th simulation done
# seed: 1024
# Equally spaced quantile knots used.
# Main: 1.5111691920483914
# Interaction: 1.4367408801350035
# induced SNR: 0.20156287052803032
# SD(Y):  5.747757253523285
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 25 th simulation done
# seed: 1025
# Equally spaced quantile knots used.
# Main: 1.3275764732482356
# Interaction: 1.421188412364943
# induced SNR: 0.2010953709804189
# SD(Y):  5.425163992583289
# Naive Selected Groups: 7
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 26 th simulation done
# seed: 1026
# Equally spaced quantile knots used.
# Main: 1.4091867818377177
# Interaction: 1.3276457359243585
# induced SNR: 0.1750170477399438
# SD(Y):  5.279012510137719
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 27 th simulation done
# seed: 1027
# Equally spaced quantile knots used.
# Main: 1.3664957392795523
# Interaction: 1.4156474033223045
# induced SNR: 0.19741832050945693
# SD(Y):  5.352002314083086
# Naive Selected Groups: 3
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 28 th simulation done
# seed: 1028
# Equally spaced quantile knots used.
# Main: 1.3168769963206
# Interaction: 1.331000493147333
# induced SNR: 0.17592759529931157
# SD(Y):  5.602584923749602
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 29 th simulation done
# seed: 1029
# Equally spaced quantile knots used.
# Main: 1.3804607893195808
# Interaction: 1.294242418308871
# induced SNR: 0.17466132978006318
# SD(Y):  5.471639425143882
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 30 th simulation done
# seed: 1030
# Equally spaced quantile knots used.
# Main: 1.4920129105398374
# Interaction: 1.3031620285377095
# induced SNR: 0.2073655851064062
# SD(Y):  5.552801207266242
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 31 th simulation done
# seed: 1031
# Equally spaced quantile knots used.
# Main: 1.3926043436109785
# Interaction: 1.5175657041256514
# induced SNR: 0.206232897449563
# SD(Y):  5.681258141582454
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 32 th simulation done
# seed: 1032
# Equally spaced quantile knots used.
# Main: 1.4121238909152345
# Interaction: 1.4659913705549523
# induced SNR: 0.2080225869129192
# SD(Y):  5.639241021085171
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 33 th simulation done
# seed: 1033
# Equally spaced quantile knots used.
# Main: 1.4073449180281712
# Interaction: 1.4221389874544808
# induced SNR: 0.20047130841732394
# SD(Y):  5.635656011315946
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 34 th simulation done
# seed: 1034
# Equally spaced quantile knots used.
# Main: 1.2803201509657145
# Interaction: 1.287370348460931
# induced SNR: 0.1515814647596228
# SD(Y):  5.179130702619683
# Naive Selected Groups: 9
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 0.0 35 th simulation done
# seed: 1035
# Equally spaced quantile knots used.
# Main: 1.4075984055693604
# Interaction: 1.4939294269516485
# induced SNR: 0.22099668331369682
# SD(Y):  5.584244611162821
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 36 th simulation done
# seed: 1036
# Equally spaced quantile knots used.
# Main: 1.461853333369412
# Interaction: 1.4156886803086097
# induced SNR: 0.19732705890319013
# SD(Y):  5.1628981245967
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 37 th simulation done
# seed: 1037
# Equally spaced quantile knots used.
# Main: 1.3804067256427075
# Interaction: 1.44261566416399
# induced SNR: 0.1992750014938584
# SD(Y):  5.0723717700562405
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 38 th simulation done
# seed: 1038
# Equally spaced quantile knots used.
# Main: 1.290278805734465
# Interaction: 1.3447435248704247
# induced SNR: 0.17546236675254429
# SD(Y):  5.644601892466804
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 39 th simulation done
# seed: 1039
# Equally spaced quantile knots used.
# Main: 1.4602697820487853
# Interaction: 1.3120599528782588
# induced SNR: 0.18303995246341107
# SD(Y):  5.234718505052676
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 40 th simulation done
# seed: 1040
# Equally spaced quantile knots used.
# Main: 1.3520749924099575
# Interaction: 1.4214659462939994
# induced SNR: 0.1878681239827719
# SD(Y):  5.393967372155614
# Naive Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 41 th simulation done
# seed: 1041
# Equally spaced quantile knots used.
# Main: 1.433248298096179
# Interaction: 1.478599331932811
# induced SNR: 0.24252512082586586
# SD(Y):  5.638404760486893
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 42 th simulation done
# seed: 1042
# Equally spaced quantile knots used.
# Main: 1.3835062783751795
# Interaction: 1.3601568196219647
# induced SNR: 0.17836167453351506
# SD(Y):  5.401353587733311
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 43 th simulation done
# seed: 1043
# Equally spaced quantile knots used.
# Main: 1.3046604707008702
# Interaction: 1.3019513938603344
# induced SNR: 0.15289503406983057
# SD(Y):  5.440063076310855
# Naive Selected Groups: 5
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 44 th simulation done
# seed: 1044
# Equally spaced quantile knots used.
# Main: 1.4362255778662052
# Interaction: 1.44812655563314
# induced SNR: 0.20528680328393942
# SD(Y):  5.3081817071209185
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 45 th simulation done
# seed: 1045
# Equally spaced quantile knots used.
# Main: 1.336503486289395
# Interaction: 1.4482460793624319
# induced SNR: 0.19472576050215154
# SD(Y):  5.727976752079197
# Naive Selected Groups: 7
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 46 th simulation done
# seed: 1046
# Equally spaced quantile knots used.
# Main: 1.3833794410571836
# Interaction: 1.478356839412411
# induced SNR: 0.20733512687868824
# SD(Y):  4.862736325385979
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 47 th simulation done
# seed: 1047
# Equally spaced quantile knots used.
# Main: 1.4086659453756032
# Interaction: 1.5205654835807534
# induced SNR: 0.22791413275228234
# SD(Y):  5.501616160934335
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 48 th simulation done
# seed: 1048
# Equally spaced quantile knots used.
# Main: 1.4244984786595187
# Interaction: 1.426638129113692
# induced SNR: 0.20229740127727916
# SD(Y):  6.009649800248288
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 49 th simulation done
# seed: 1049
# Equally spaced quantile knots used.
# Main: 1.4795704260454616
# Interaction: 1.4274511871032132
# induced SNR: 0.22628115405845162
# SD(Y):  5.6723447981413955
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 50 th simulation done
# seed: 1050
# Equally spaced quantile knots used.
# Main: 1.3170074540008008
# Interaction: 1.4088658207536189
# induced SNR: 0.19728752019584633
# SD(Y):  5.0991607054621655
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 51 th simulation done
# seed: 1051
# Equally spaced quantile knots used.
# Main: 1.3399346072964629
# Interaction: 1.3739289003667325
# induced SNR: 0.19046265999168127
# SD(Y):  5.994019070573375
# Naive Selected Groups: 9
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 52 th simulation done
# seed: 1052
# Equally spaced quantile knots used.
# Main: 1.2757273577211012
# Interaction: 1.3946025168863578
# induced SNR: 0.17778527730225072
# SD(Y):  5.43324828945841
# Naive Selected Groups: 6
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 53 th simulation done
# seed: 1053
# Equally spaced quantile knots used.
# Main: 1.3623446386591815
# Interaction: 1.4201926721603648
# induced SNR: 0.19133192458378373
# SD(Y):  5.662073782479598
# Naive Selected Groups: 6
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 54 th simulation done
# seed: 1054
# Equally spaced quantile knots used.
# Main: 1.478796049890953
# Interaction: 1.331256788816858
# induced SNR: 0.20292017851728505
# SD(Y):  5.530962161386799
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 55 th simulation done
# seed: 1055
# Equally spaced quantile knots used.
# Main: 1.334268028212055
# Interaction: 1.3814750381030487
# induced SNR: 0.19099415140624001
# SD(Y):  4.887196460933017
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.0 56 th simulation done
# seed: 1056
# Equally spaced quantile knots used.
# Main: 1.5377625117752356
# Interaction: 1.3754254028103643
# induced SNR: 0.21993574712374991
# SD(Y):  5.411793337030265
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 57 th simulation done
# seed: 1057
# Equally spaced quantile knots used.
# Main: 1.3923786358037156
# Interaction: 1.4540767595774169
# induced SNR: 0.216475137131263
# SD(Y):  5.51807609206211
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 58 th simulation done
# seed: 1058
# Equally spaced quantile knots used.
# Main: 1.327447554736045
# Interaction: 1.4492502064196742
# induced SNR: 0.1859718157667556
# SD(Y):  5.42760732995909
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 59 th simulation done
# seed: 1059
# Equally spaced quantile knots used.
# Main: 1.3743968380396008
# Interaction: 1.4052474727563964
# induced SNR: 0.19571167854025204
# SD(Y):  5.548812546357307
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 60 th simulation done
# seed: 1060
# Equally spaced quantile knots used.
# Main: 1.4088506591446743
# Interaction: 1.366559285207794
# induced SNR: 0.1812158649270924
# SD(Y):  5.371414653207054
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 61 th simulation done
# seed: 1061
# Equally spaced quantile knots used.
# Main: 1.372881076473805
# Interaction: 1.4162759617329508
# induced SNR: 0.19815988753114355
# SD(Y):  5.310387221922431
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 62 th simulation done
# seed: 1062
# Equally spaced quantile knots used.
# Main: 1.423133298377429
# Interaction: 1.2774721881155744
# induced SNR: 0.1778299955953832
# SD(Y):  5.675488130716462
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 63 th simulation done
# seed: 1063
# Equally spaced quantile knots used.
# Main: 1.407065180878577
# Interaction: 1.355274123328692
# induced SNR: 0.19403177988334375
# SD(Y):  5.510122957661722
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 64 th simulation done
# seed: 1064
# Equally spaced quantile knots used.
# Main: 1.406147648460664
# Interaction: 1.4691441655936244
# induced SNR: 0.20730346021607882
# SD(Y):  6.085784123777414
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 65 th simulation done
# seed: 1065
# Equally spaced quantile knots used.
# Main: 1.3498856874313665
# Interaction: 1.3800331887472517
# induced SNR: 0.1873152829376823
# SD(Y):  5.7533904712007065
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 66 th simulation done
# seed: 1066
# Equally spaced quantile knots used.
# Main: 1.4476744766763996
# Interaction: 1.5251568296134577
# induced SNR: 0.23962907622017393
# SD(Y):  6.335850409614309
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 67 th simulation done
# seed: 1067
# Equally spaced quantile knots used.
# Main: 1.4249752814144585
# Interaction: 1.3788614644597286
# induced SNR: 0.19400648172975443
# SD(Y):  4.792379489055828
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 68 th simulation done
# seed: 1068
# Equally spaced quantile knots used.
# Main: 1.4576682449542568
# Interaction: 1.4429424950000103
# induced SNR: 0.21795119523999806
# SD(Y):  5.492553031623319
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 69 th simulation done
# seed: 1069
# Equally spaced quantile knots used.
# Main: 1.3482098104229017
# Interaction: 1.468312694442132
# induced SNR: 0.21096362451338516
# SD(Y):  5.054386049041855
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 70 th simulation done
# seed: 1070
# Equally spaced quantile knots used.
# Main: 1.3407981961204425
# Interaction: 1.2956642969063106
# induced SNR: 0.1684086785064385
# SD(Y):  5.041925269044058
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 71 th simulation done
# seed: 1071
# Equally spaced quantile knots used.
# Main: 1.4749989845910367
# Interaction: 1.4162803970493092
# induced SNR: 0.21661349947566647
# SD(Y):  5.84549740916001
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 72 th simulation done
# seed: 1072
# Equally spaced quantile knots used.
# Main: 1.5069699730231034
# Interaction: 1.3683282027531583
# induced SNR: 0.22760986098009262
# SD(Y):  5.56908548270924
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 73 th simulation done
# seed: 1073
# Equally spaced quantile knots used.
# Main: 1.4541933673708276
# Interaction: 1.306002578298864
# induced SNR: 0.1935196109182389
# SD(Y):  5.055542078462406
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 74 th simulation done
# seed: 1074
# Equally spaced quantile knots used.
# Main: 1.4179574906798063
# Interaction: 1.4445577061165045
# induced SNR: 0.21733092432810772
# SD(Y):  5.561252050253823
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 75 th simulation done
# seed: 1075
# Equally spaced quantile knots used.
# Main: 1.4638986843183
# Interaction: 1.393158163302556
# induced SNR: 0.21754210215491435
# SD(Y):  5.423073207278956
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 76 th simulation done
# seed: 1076
# Equally spaced quantile knots used.
# Main: 1.4168396363877205
# Interaction: 1.3394477957526956
# induced SNR: 0.18282793299175765
# SD(Y):  5.16714643566095
# Naive Selected Groups: 8
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 77 th simulation done
# seed: 1077
# Equally spaced quantile knots used.
# Main: 1.494669723031231
# Interaction: 1.3598736457929308
# induced SNR: 0.21371397310475826
# SD(Y):  4.708468919253179
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# 0.0 78 th simulation done
# seed: 1078
# Equally spaced quantile knots used.
# Main: 1.4300715711550984
# Interaction: 1.4915050457205097
# induced SNR: 0.2106781532682276
# SD(Y):  5.642679439226516
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 79 th simulation done
# seed: 1079
# Equally spaced quantile knots used.
# Main: 1.3636850162547045
# Interaction: 1.3767568341661753
# induced SNR: 0.19586135652328845
# SD(Y):  5.339837310105252
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 80 th simulation done
# seed: 1080
# Equally spaced quantile knots used.
# Main: 1.4168473854066412
# Interaction: 1.508575603494505
# induced SNR: 0.22607372933349879
# SD(Y):  5.818071539496307
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 81 th simulation done
# seed: 1081
# Equally spaced quantile knots used.
# Main: 1.3986691293034876
# Interaction: 1.4988106674518429
# induced SNR: 0.22377488239616833
# SD(Y):  5.262258446493262
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 82 th simulation done
# seed: 1082
# Equally spaced quantile knots used.
# Main: 1.3315220468934261
# Interaction: 1.5554778912906169
# induced SNR: 0.22158583698400347
# SD(Y):  5.634674447031592
# Naive Selected Groups: 7
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.0 83 th simulation done
# seed: 1083
# Equally spaced quantile knots used.
# Main: 1.329172794228857
# Interaction: 1.4432781626667694
# induced SNR: 0.18540397872153513
# SD(Y):  5.288289285933148
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 84 th simulation done
# seed: 1084
# Equally spaced quantile knots used.
# Main: 1.5300946518713476
# Interaction: 1.4330281100676923
# induced SNR: 0.22350620750059164
# SD(Y):  5.189660664769369
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 85 th simulation done
# seed: 1085
# Equally spaced quantile knots used.
# Main: 1.42962546583469
# Interaction: 1.4667885925222608
# induced SNR: 0.22590049462131132
# SD(Y):  5.880330958712794
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 86 th simulation done
# seed: 1086
# Equally spaced quantile knots used.
# Main: 1.4444934893789299
# Interaction: 1.4846901543922466
# induced SNR: 0.22212387225082872
# SD(Y):  5.56119706793846
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 87 th simulation done
# seed: 1087
# Equally spaced quantile knots used.
# Main: 1.4234953132189296
# Interaction: 1.4111337850288792
# induced SNR: 0.1970347942664149
# SD(Y):  5.5521319399227975
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 88 th simulation done
# seed: 1088
# Equally spaced quantile knots used.
# Main: 1.335800884085333
# Interaction: 1.422503719778641
# induced SNR: 0.18942893798493368
# SD(Y):  5.027505102584572
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 89 th simulation done
# seed: 1089
# Equally spaced quantile knots used.
# Main: 1.3065302972182526
# Interaction: 1.4455343784278591
# induced SNR: 0.19256006347745466
# SD(Y):  5.0251757152816845
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 90 th simulation done
# seed: 1090
# Equally spaced quantile knots used.
# Main: 1.3858101662908473
# Interaction: 1.2019720337435316
# induced SNR: 0.1573154085247978
# SD(Y):  5.6596281228495045
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 91 th simulation done
# seed: 1091
# Equally spaced quantile knots used.
# Main: 1.429352735772528
# Interaction: 1.3803731206079657
# induced SNR: 0.20109496137524918
# SD(Y):  5.374218011364546
# Naive Selected Groups: 3
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 92 th simulation done
# seed: 1092
# Equally spaced quantile knots used.
# Main: 1.23284185041882
# Interaction: 1.4924520298042891
# induced SNR: 0.18541807584845107
# SD(Y):  5.485852815682656
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 93 th simulation done
# seed: 1093
# Equally spaced quantile knots used.
# Main: 1.4129472810224204
# Interaction: 1.3931941411034499
# induced SNR: 0.20329076947535138
# SD(Y):  5.312286816444319
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 94 th simulation done
# seed: 1094
# Equally spaced quantile knots used.
# Main: 1.4093905036182317
# Interaction: 1.4108012449829959
# induced SNR: 0.19798741355917546
# SD(Y):  5.0668443803156595
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 95 th simulation done
# seed: 1095
# Equally spaced quantile knots used.
# Main: 1.502399393930823
# Interaction: 1.3779403775962895
# induced SNR: 0.23661124747953635
# SD(Y):  5.4108471401518266
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 96 th simulation done
# seed: 1096
# Equally spaced quantile knots used.
# Main: 1.39161072551234
# Interaction: 1.4681485500252658
# induced SNR: 0.21995599262911356
# SD(Y):  5.396606429766735
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 97 th simulation done
# seed: 1097
# Equally spaced quantile knots used.
# Main: 1.3578929702585232
# Interaction: 1.56518376925046
# induced SNR: 0.20911576905353768
# SD(Y):  5.351136820192841
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 98 th simulation done
# seed: 1098
# Equally spaced quantile knots used.
# Main: 1.442897764081397
# Interaction: 1.233854564834844
# induced SNR: 0.1827927229583745
# SD(Y):  5.521094207900825
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 99 th simulation done
# seed: 1099
# Equally spaced quantile knots used.
# Main: 1.327947720061429
# Interaction: 1.4638605267832032
# induced SNR: 0.19770015527538148
# SD(Y):  5.292336783329622
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 100 th simulation done
# seed: 1100
# Equally spaced quantile knots used.
# Main: 1.2694098993720644
# Interaction: 1.4931627451119518
# induced SNR: 0.2013257423788138
# SD(Y):  5.484941082275731
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 101 th simulation done
# seed: 1101
# Equally spaced quantile knots used.
# Main: 1.3203743734255817
# Interaction: 1.4505043679820502
# induced SNR: 0.20272248695980322
# SD(Y):  5.667590889020972
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 102 th simulation done
# seed: 1102
# Equally spaced quantile knots used.
# Main: 1.3791043914744627
# Interaction: 1.3329451335008944
# induced SNR: 0.19353555828451754
# SD(Y):  5.455759549469256
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 103 th simulation done
# seed: 1103
# Equally spaced quantile knots used.
# Main: 1.4475582484169713
# Interaction: 1.3225126026743625
# induced SNR: 0.19588966286917806
# SD(Y):  5.4046708658813705
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 104 th simulation done
# seed: 1104
# Equally spaced quantile knots used.
# Main: 1.417496794938045
# Interaction: 1.4987444077995609
# induced SNR: 0.23839104482262685
# SD(Y):  5.089270405290577
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 105 th simulation done
# seed: 1105
# Equally spaced quantile knots used.
# Main: 1.387589425387769
# Interaction: 1.271222709709877
# induced SNR: 0.16618231917134085
# SD(Y):  5.8192190415189256
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 106 th simulation done
# seed: 1106
# Equally spaced quantile knots used.
# Main: 1.3198097449151496
# Interaction: 1.4708432446743793
# induced SNR: 0.19775898786299442
# SD(Y):  5.570105657122643
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 107 th simulation done
# seed: 1107
# Equally spaced quantile knots used.
# Main: 1.4322372626175286
# Interaction: 1.4045578473397107
# induced SNR: 0.1992097795701116
# SD(Y):  6.1105965222297005
# Naive Selected Groups: 7
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 108 th simulation done
# seed: 1108
# Equally spaced quantile knots used.
# Main: 1.3789137754861278
# Interaction: 1.3821599171508558
# induced SNR: 0.19086957605865826
# SD(Y):  5.048201185243224
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 109 th simulation done
# seed: 1109
# Equally spaced quantile knots used.
# Main: 1.4690141235796583
# Interaction: 1.332468175870603
# induced SNR: 0.20123719295558792
# SD(Y):  5.878745223485493
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.0 110 th simulation done
# seed: 1110
# Equally spaced quantile knots used.
# Main: 1.442072087911715
# Interaction: 1.2570435052597084
# induced SNR: 0.17275701903795992
# SD(Y):  5.360395258262015
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 111 th simulation done
# seed: 1111
# Equally spaced quantile knots used.
# Main: 1.534568413647771
# Interaction: 1.2825638014978802
# induced SNR: 0.2047943919782169
# SD(Y):  5.922548953007214
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 112 th simulation done
# seed: 1112
# Equally spaced quantile knots used.
# Main: 1.4842557618456127
# Interaction: 1.4584355965860791
# induced SNR: 0.2284873343505752
# SD(Y):  5.273953928344529
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 113 th simulation done
# seed: 1113
# Equally spaced quantile knots used.
# Main: 1.3727183050284262
# Interaction: 1.4692836622301517
# induced SNR: 0.193714641240143
# SD(Y):  5.2745139552358395
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 114 th simulation done
# seed: 1114
# Equally spaced quantile knots used.
# Main: 1.3296061435658526
# Interaction: 1.4192455158532005
# induced SNR: 0.19499539529571114
# SD(Y):  5.7379800068701465
# DS Selected Groups: 2
# Data Carving Randomization Used
# 0.0 115 th simulation done
# seed: 1115
# Equally spaced quantile knots used.
# Main: 1.3620393485416833
# Interaction: 1.521657859481933
# induced SNR: 0.20267089426416207
# SD(Y):  5.47583203449159
# Naive Selected Groups: 7
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.0 116 th simulation done
# seed: 1116
# Equally spaced quantile knots used.
# Main: 1.4667534844290233
# Interaction: 1.3840638025035974
# induced SNR: 0.21006727570991943
# SD(Y):  5.000851280979512
# Naive Selected Groups: 5
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 117 th simulation done
# seed: 1117
# Equally spaced quantile knots used.
# Main: 1.4072875744120583
# Interaction: 1.3706457603354911
# induced SNR: 0.1852228209204962
# SD(Y):  5.569793271918247
# DS Selected Groups: 2
# Data Carving Randomization Used
# 0.0 118 th simulation done
# seed: 1118
# Equally spaced quantile knots used.
# Main: 1.431764422725848
# Interaction: 1.3991333377739548
# induced SNR: 0.18992980093847642
# SD(Y):  5.2561579032857
# Naive Selected Groups: 8
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 119 th simulation done
# seed: 1119
# Equally spaced quantile knots used.
# Main: 1.42120009980209
# Interaction: 1.318570472253818
# induced SNR: 0.20385018596130702
# SD(Y):  5.247045216350002
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 120 th simulation done
# seed: 1120
# Equally spaced quantile knots used.
# Main: 1.2926257626289537
# Interaction: 1.3354867883258983
# induced SNR: 0.17155699117413775
# SD(Y):  5.321448205682806
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 121 th simulation done
# seed: 1121
# Equally spaced quantile knots used.
# Main: 1.4756531668291843
# Interaction: 1.4112730404028455
# induced SNR: 0.2092708607885659
# SD(Y):  6.008046346619348
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 122 th simulation done
# seed: 1122
# Equally spaced quantile knots used.
# Main: 1.4738993282412605
# Interaction: 1.1961935481815391
# induced SNR: 0.1882239585530496
# SD(Y):  5.2911941030287
# Naive Selected Groups: 5
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 123 th simulation done
# seed: 1123
# Equally spaced quantile knots used.
# Main: 1.5036654838169206
# Interaction: 1.5742439330705615
# induced SNR: 0.24005149359763703
# SD(Y):  5.546460305815076
# Naive Selected Groups: 4
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 124 th simulation done
# seed: 1124
# Equally spaced quantile knots used.
# Main: 1.402851938200049
# Interaction: 1.4009530280704892
# induced SNR: 0.19578709839464076
# SD(Y):  5.424893810648688
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 125 th simulation done
# seed: 1125
# Equally spaced quantile knots used.
# Main: 1.4563691294765995
# Interaction: 1.456119551412541
# induced SNR: 0.21582661863031785
# SD(Y):  5.934467445265555
# Naive Selected Groups: 6
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 126 th simulation done
# seed: 1126
# Equally spaced quantile knots used.
# Main: 1.3482312869171225
# Interaction: 1.334359817478035
# induced SNR: 0.17396063509040727
# SD(Y):  5.331464262803974
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 127 th simulation done
# seed: 1127
# Equally spaced quantile knots used.
# Main: 1.4286528674631893
# Interaction: 1.3845464575448019
# induced SNR: 0.18941309102617904
# SD(Y):  5.528185021812649
# Naive Selected Groups: 6
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 128 th simulation done
# seed: 1128
# Equally spaced quantile knots used.
# Main: 1.2836732087504077
# Interaction: 1.4895798600488626
# induced SNR: 0.18758666697131385
# SD(Y):  5.64776326510963
# Naive Selected Groups: 8
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.0 129 th simulation done
# seed: 1129
# Equally spaced quantile knots used.
# Main: 1.4160114178959322
# Interaction: 1.4156075398741577
# induced SNR: 0.20093343898167956
# SD(Y):  5.803057309278906
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 130 th simulation done
# seed: 1130
# Equally spaced quantile knots used.
# Main: 1.4574466132479114
# Interaction: 1.365921496424263
# induced SNR: 0.20290918881334108
# SD(Y):  5.656472692072184
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 131 th simulation done
# seed: 1131
# Equally spaced quantile knots used.
# Main: 1.3600453721216605
# Interaction: 1.4176712216433478
# induced SNR: 0.19304593912220527
# SD(Y):  6.320327212094495
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 132 th simulation done
# seed: 1132
# Equally spaced quantile knots used.
# Main: 1.4186617452931864
# Interaction: 1.419151141520784
# induced SNR: 0.21159376998545468
# SD(Y):  5.656990005115921
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 133 th simulation done
# seed: 1133
# Equally spaced quantile knots used.
# Main: 1.4670993892946396
# Interaction: 1.486992285203473
# induced SNR: 0.22675133065336525
# SD(Y):  5.1840337673922505
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 134 th simulation done
# seed: 1134
# Equally spaced quantile knots used.
# Main: 1.4655780067970132
# Interaction: 1.4496156379306169
# induced SNR: 0.20343752583208405
# SD(Y):  5.0631515990969405
# Naive Selected Groups: 5
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 135 th simulation done
# seed: 1135
# Equally spaced quantile knots used.
# Main: 1.3752421568460367
# Interaction: 1.5024446669724267
# induced SNR: 0.21472242896391908
# SD(Y):  5.898839192314327
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.0 136 th simulation done
# seed: 1136
# Equally spaced quantile knots used.
# Main: 1.411452060993657
# Interaction: 1.3953914815268542
# induced SNR: 0.18923930343061046
# SD(Y):  5.713597679693809
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 137 th simulation done
# seed: 1137
# Equally spaced quantile knots used.
# Main: 1.4116989753750875
# Interaction: 1.4930263037626608
# induced SNR: 0.21254329465365132
# SD(Y):  5.517120012068024
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 138 th simulation done
# seed: 1138
# Equally spaced quantile knots used.
# Main: 1.46408466787227
# Interaction: 1.4841013456960657
# induced SNR: 0.22321748064298977
# SD(Y):  5.440581907377653
# Naive Selected Groups: 8
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 0.0 139 th simulation done
# seed: 1139
# Equally spaced quantile knots used.
# Main: 1.3208569953908802
# Interaction: 1.4534376179398618
# induced SNR: 0.21472410535106912
# SD(Y):  5.831859652118582
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 140 th simulation done
# seed: 1140
# Equally spaced quantile knots used.
# Main: 1.3254428069692807
# Interaction: 1.445299833694248
# induced SNR: 0.19359467315135354
# SD(Y):  5.526506861925753
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.0 141 th simulation done
# seed: 1141
# Equally spaced quantile knots used.
# Main: 1.387829431954812
# Interaction: 1.3737934662989995
# induced SNR: 0.18797458279148338
# SD(Y):  5.257737602548588
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 142 th simulation done
# seed: 1142
# Equally spaced quantile knots used.
# Main: 1.3858270010235325
# Interaction: 1.4625883339001697
# induced SNR: 0.21845195959623429
# SD(Y):  5.545050145418787
# Naive Selected Groups: 3
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 143 th simulation done
# seed: 1143
# Equally spaced quantile knots used.
# Main: 1.4175607036422582
# Interaction: 1.2925606969312844
# induced SNR: 0.17915271779319886
# SD(Y):  5.306243142444109
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 144 th simulation done
# seed: 1144
# Equally spaced quantile knots used.
# Main: 1.4873749929591875
# Interaction: 1.2885338301313183
# induced SNR: 0.19537086089188743
# SD(Y):  5.230979133858885
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 145 th simulation done
# seed: 1145
# Equally spaced quantile knots used.
# Main: 1.4613056164605736
# Interaction: 1.3773757647777802
# induced SNR: 0.19462759203493074
# SD(Y):  5.536225570539854
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 146 th simulation done
# seed: 1146
# Equally spaced quantile knots used.
# Main: 1.367054896761706
# Interaction: 1.4142033094443283
# induced SNR: 0.1963206454954363
# SD(Y):  5.727670931952569
# Naive Selected Groups: 6
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 147 th simulation done
# seed: 1147
# Equally spaced quantile knots used.
# Main: 1.3465328406064156
# Interaction: 1.3096914695255435
# induced SNR: 0.185696846417665
# SD(Y):  5.169964496349179
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 148 th simulation done
# seed: 1148
# Equally spaced quantile knots used.
# Main: 1.445100115884122
# Interaction: 1.512919601277824
# induced SNR: 0.22259046900130164
# SD(Y):  5.441910606794445
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 149 th simulation done
# seed: 1149
# Equally spaced quantile knots used.
# Main: 1.384332309517367
# Interaction: 1.3800236096987601
# induced SNR: 0.19682007027680679
# SD(Y):  5.3990565215593405
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 150 th simulation done
# seed: 1150
# Equally spaced quantile knots used.
# Main: 1.344956104965674
# Interaction: 1.4125773765787069
# induced SNR: 0.19171869027661564
# SD(Y):  5.524121338591724
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 151 th simulation done
# seed: 1151
# Equally spaced quantile knots used.
# Main: 1.4398817788913227
# Interaction: 1.2746484443614317
# induced SNR: 0.17907500742345925
# SD(Y):  5.273704390871501
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 152 th simulation done
# seed: 1152
# Equally spaced quantile knots used.
# Main: 1.397743785105036
# Interaction: 1.3652310602333413
# induced SNR: 0.1756488597728844
# SD(Y):  5.507224814915278
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 153 th simulation done
# seed: 1153
# Equally spaced quantile knots used.
# Main: 1.3301507667772177
# Interaction: 1.3535946757841937
# induced SNR: 0.1765979706864656
# SD(Y):  5.233384180778685
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 154 th simulation done
# seed: 1154
# Equally spaced quantile knots used.
# Main: 1.5109825738895555
# Interaction: 1.3609939259285637
# induced SNR: 0.21814949788511842
# SD(Y):  5.759272218928726
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 155 th simulation done
# seed: 1155
# Equally spaced quantile knots used.
# Main: 1.4681043437302304
# Interaction: 1.3433287973824546
# induced SNR: 0.215225479469171
# SD(Y):  5.543232566274278
# Naive Selected Groups: 4
# DS Selected Groups: 2
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 156 th simulation done
# seed: 1156
# Equally spaced quantile knots used.
# Main: 1.3549936803945837
# Interaction: 1.4574923730582483
# induced SNR: 0.17311736275585266
# SD(Y):  5.7194982693261815
# Naive Selected Groups: 7
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 157 th simulation done
# seed: 1157
# Equally spaced quantile knots used.
# Main: 1.3837755913404748
# Interaction: 1.3261927845031425
# induced SNR: 0.19561097186917778
# SD(Y):  5.8512637848228
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 158 th simulation done
# seed: 1158
# Equally spaced quantile knots used.
# Main: 1.4590240195608897
# Interaction: 1.3741870061880403
# induced SNR: 0.20588939522473523
# SD(Y):  5.589926283867169
# Naive Selected Groups: 3
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.0 159 th simulation done
# seed: 1159
# Equally spaced quantile knots used.
# Main: 1.357666359341833
# Interaction: 1.4136470038474807
# induced SNR: 0.19894887622251534
# SD(Y):  5.7380943220269875
# Naive Selected Groups: 4
# DS Selected Groups: 3
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 160 th simulation done
# seed: 1160
# Equally spaced quantile knots used.
# Main: 1.4424440822151505
# Interaction: 1.4584003685061666
# induced SNR: 0.22214731844014127
# SD(Y):  5.43227854843754
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 161 th simulation done
# seed: 1161
# Equally spaced quantile knots used.
# Main: 1.462735510786173
# Interaction: 1.4305583654594705
# induced SNR: 0.2182375910738816
# SD(Y):  5.628636738933596
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.0 162 th simulation done
# seed: 1162
# Equally spaced quantile knots used.
# Main: 1.394715481776462
# Interaction: 1.428894249587635
# induced SNR: 0.20908557868541183
# SD(Y):  5.358731962506285
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 163 th simulation done
# seed: 1163
# Equally spaced quantile knots used.
# Main: 1.380462660759879
# Interaction: 1.3472026281708886
# induced SNR: 0.16122884743032984
# SD(Y):  5.3681171687414935
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.0 164 th simulation done
# seed: 1164
# Equally spaced quantile knots used.
# Main: 1.2677464102455465
# Interaction: 1.633362882676463
# induced SNR: 0.22107470522236486
# SD(Y):  5.304545680202288
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.0 165 th simulation done
# seed: 1165
# Equally spaced quantile knots used.
# Main: 1.4396104845685085
# Interaction: 1.3308926042183709
# induced SNR: 0.19219731043222504
# SD(Y):  4.990741647315177
# ...
# induced SNR: 0.5286497068768493
# SD(Y):  5.841605803089142
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.6 145 th simulation done
# seed: 1145
# Equally spaced quantile knots used.
# Main: 1.4148300009913497
# Interaction: 2.3126777104157297
# induced SNR: 0.4697996741185239
# SD(Y):  5.846954313225702
# Naive Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 0.6 146 th simulation done
# seed: 1146
# Equally spaced quantile knots used.
# Main: 1.3755089130440468
# Interaction: 2.3000460736966937
# induced SNR: 0.45899743638042023
# SD(Y):  5.9942336828279545
# Naive Selected Groups: 8
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 147 th simulation done
# seed: 1147
# Equally spaced quantile knots used.
# Main: 1.4514553953622311
# Interaction: 2.2495901129174816
# induced SNR: 0.4489358740463888
# SD(Y):  5.806137708831554
# Naive Selected Groups: 5
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 3
# 0.6 148 th simulation done
# seed: 1148
# Equally spaced quantile knots used.
# Main: 1.514522074340735
# Interaction: 2.3549739165947963
# induced SNR: 0.4989970098453407
# SD(Y):  5.887667184530749
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 149 th simulation done
# seed: 1149
# Equally spaced quantile knots used.
# Main: 1.4253690365918155
# Interaction: 2.3518769462233315
# induced SNR: 0.483309451774472
# SD(Y):  6.034734585737958
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 0.6 150 th simulation done
# seed: 1150
# Equally spaced quantile knots used.
# Main: 1.2978677857975105
# Interaction: 2.305312006480588
# induced SNR: 0.4443132670684553
# SD(Y):  5.905050330737468
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 151 th simulation done
# seed: 1151
# Equally spaced quantile knots used.
# Main: 1.3673989330424818
# Interaction: 2.3888707535603904
# induced SNR: 0.47977994161927034
# SD(Y):  5.884627914134657
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 152 th simulation done
# seed: 1152
# Equally spaced quantile knots used.
# Main: 1.435441590841299
# Interaction: 2.3132145776352298
# induced SNR: 0.4785602943362424
# SD(Y):  5.604941473730274
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.6 153 th simulation done
# seed: 1153
# Equally spaced quantile knots used.
# Main: 1.3899242379774308
# Interaction: 2.298541314755306
# induced SNR: 0.4690571746138067
# SD(Y):  5.728523741683668
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.6 154 th simulation done
# seed: 1154
# Equally spaced quantile knots used.
# Main: 1.3966279008680544
# Interaction: 2.420381572410165
# induced SNR: 0.5076963170092257
# SD(Y):  6.367078547045056
# Naive Selected Groups: 8
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 155 th simulation done
# seed: 1155
# Equally spaced quantile knots used.
# Main: 1.417937786460886
# Interaction: 2.4476346969315332
# induced SNR: 0.5204822107794874
# SD(Y):  6.79144674929045
# Naive Selected Groups: 8
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 0.6 156 th simulation done
# seed: 1156
# Equally spaced quantile knots used.
# Main: 1.3979464443335692
# Interaction: 2.2618863711451223
# induced SNR: 0.44521832125737737
# SD(Y):  6.016681726142512
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 157 th simulation done
# seed: 1157
# Equally spaced quantile knots used.
# Main: 1.3562876154355348
# Interaction: 2.3093407153826977
# induced SNR: 0.4542017902545254
# SD(Y):  5.915768674638902
# Naive Selected Groups: 8
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 158 th simulation done
# seed: 1158
# Equally spaced quantile knots used.
# Main: 1.4327326202040185
# Interaction: 2.516647029117867
# induced SNR: 0.5433633186773114
# SD(Y):  5.905093611584479
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 159 th simulation done
# seed: 1159
# Equally spaced quantile knots used.
# Main: 1.4365974776032229
# Interaction: 2.2332145738057414
# induced SNR: 0.4575901674643284
# SD(Y):  6.744915949234923
# Naive Selected Groups: 9
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 0.6 160 th simulation done
# seed: 1160
# Equally spaced quantile knots used.
# Main: 1.4169937444275176
# Interaction: 2.37871939904697
# induced SNR: 0.5015888284883099
# SD(Y):  5.756708610043299
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 161 th simulation done
# seed: 1161
# Equally spaced quantile knots used.
# Main: 1.41409623413351
# Interaction: 2.582024249999327
# induced SNR: 0.5598088835728596
# SD(Y):  6.134871671904181
# Naive Selected Groups: 8
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 0.6 162 th simulation done
# seed: 1162
# Equally spaced quantile knots used.
# Main: 1.4444625977275674
# Interaction: 2.2661012979847226
# induced SNR: 0.4716830917315383
# SD(Y):  6.0326111579398365
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 0.6 163 th simulation done
# seed: 1163
# Equally spaced quantile knots used.
# Main: 1.3040436660179318
# Interaction: 2.269955138410206
# induced SNR: 0.43339192825327116
# SD(Y):  5.96662941271932
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 164 th simulation done
# seed: 1164
# Equally spaced quantile knots used.
# Main: 1.3598894770065586
# Interaction: 2.344066406295244
# induced SNR: 0.45849847695307683
# SD(Y):  6.237650627377948
# Naive Selected Groups: 5
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.6 165 th simulation done
# seed: 1165
# Equally spaced quantile knots used.
# Main: 1.3605654392684743
# Interaction: 2.4101176735866248
# induced SNR: 0.48193390053297047
# SD(Y):  5.958536201345171
# Naive Selected Groups: 7
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 166 th simulation done
# seed: 1166
# Equally spaced quantile knots used.
# Main: 1.473288185081806
# Interaction: 2.411253699003634
# induced SNR: 0.509717403659784
# SD(Y):  6.26278682265195
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 167 th simulation done
# seed: 1167
# Equally spaced quantile knots used.
# Main: 1.3427187868103245
# Interaction: 2.3108175841860987
# induced SNR: 0.46310651723919266
# SD(Y):  5.675005970091106
# Naive Selected Groups: 6
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 168 th simulation done
# seed: 1168
# Equally spaced quantile knots used.
# Main: 1.3675268966794085
# Interaction: 2.2293334751610945
# induced SNR: 0.43898243294139105
# SD(Y):  6.079260587453075
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 169 th simulation done
# seed: 1169
# Equally spaced quantile knots used.
# Main: 1.4176728839211963
# Interaction: 2.3562197771707143
# induced SNR: 0.48878926749431717
# SD(Y):  7.0901650015716715
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 170 th simulation done
# seed: 1170
# Equally spaced quantile knots used.
# Main: 1.4092969885481084
# Interaction: 2.583249956059595
# induced SNR: 0.550920482004907
# SD(Y):  6.760506443893833
# Naive Selected Groups: 8
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 171 th simulation done
# seed: 1171
# Equally spaced quantile knots used.
# Main: 1.31738422984042
# Interaction: 2.549520523848959
# induced SNR: 0.5130323823774575
# SD(Y):  6.1839332092849615
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 0.6 172 th simulation done
# seed: 1172
# Equally spaced quantile knots used.
# Main: 1.3792359639485112
# Interaction: 2.2576147934865642
# induced SNR: 0.45082749638021796
# SD(Y):  5.99714642726545
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 173 th simulation done
# seed: 1173
# Equally spaced quantile knots used.
# Main: 1.3594303448624188
# Interaction: 2.3090016725075975
# induced SNR: 0.46196300397736073
# SD(Y):  5.643976627041945
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 174 th simulation done
# seed: 1174
# Equally spaced quantile knots used.
# Main: 1.4470390358068879
# Interaction: 2.499192796137886
# induced SNR: 0.5307101715363262
# SD(Y):  6.15816420575048
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.6 175 th simulation done
# seed: 1175
# Equally spaced quantile knots used.
# Main: 1.368380573414043
# Interaction: 2.35262441435734
# induced SNR: 0.47519878807628485
# SD(Y):  6.064911956018999
# Naive Selected Groups: 7
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 176 th simulation done
# seed: 1176
# Equally spaced quantile knots used.
# Main: 1.374210365724273
# Interaction: 2.3593159260904506
# induced SNR: 0.47364406133768067
# SD(Y):  5.943250914620438
# Naive Selected Groups: 8
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 177 th simulation done
# seed: 1177
# Equally spaced quantile knots used.
# Main: 1.4381272975476018
# Interaction: 2.1490799765281694
# induced SNR: 0.42784815715581914
# SD(Y):  5.7619785880149434
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 178 th simulation done
# seed: 1178
# Equally spaced quantile knots used.
# Main: 1.4806757084278086
# Interaction: 2.5194354518592457
# induced SNR: 0.5554175654367672
# SD(Y):  6.537824795251931
# Naive Selected Groups: 11
# Data Carving Randomization Used
# MLE Selected Groups: 10
# 0.6 179 th simulation done
# seed: 1179
# Equally spaced quantile knots used.
# Main: 1.4404587193503662
# Interaction: 2.307886451011902
# induced SNR: 0.4700821559784051
# SD(Y):  6.005102924929983
# Naive Selected Groups: 6
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 180 th simulation done
# seed: 1180
# Equally spaced quantile knots used.
# Main: 1.436152259388314
# Interaction: 2.3826433520522996
# induced SNR: 0.49863791285867465
# SD(Y):  5.58434395889754
# Naive Selected Groups: 4
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.6 181 th simulation done
# seed: 1181
# Equally spaced quantile knots used.
# Main: 1.4796426567438148
# Interaction: 2.37475515171309
# induced SNR: 0.5031970336811138
# SD(Y):  5.213646715157235
# Naive Selected Groups: 7
# DS Selected Groups: 9
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 182 th simulation done
# seed: 1182
# Equally spaced quantile knots used.
# Main: 1.4020251502256587
# Interaction: 2.3899209060126148
# induced SNR: 0.49945360454364424
# SD(Y):  5.772565468335295
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 0.6 183 th simulation done
# seed: 1183
# Equally spaced quantile knots used.
# Main: 1.4470579846679978
# Interaction: 2.3439923879236058
# induced SNR: 0.4885559481421581
# SD(Y):  6.732928841873445
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 184 th simulation done
# seed: 1184
# Equally spaced quantile knots used.
# Main: 1.344586744540822
# Interaction: 2.383064718153891
# induced SNR: 0.48138835791816836
# SD(Y):  5.879291364488596
# Naive Selected Groups: 6
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 4
# 0.6 185 th simulation done
# seed: 1185
# Equally spaced quantile knots used.
# Main: 1.3528239384937446
# Interaction: 2.169727278974073
# induced SNR: 0.4228940534296066
# SD(Y):  5.866930966477307
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 186 th simulation done
# seed: 1186
# Equally spaced quantile knots used.
# Main: 1.386984199538322
# Interaction: 2.267549901449222
# induced SNR: 0.4545223628174627
# SD(Y):  6.1222423979453655
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 0.6 187 th simulation done
# seed: 1187
# Equally spaced quantile knots used.
# Main: 1.364310413067091
# Interaction: 2.2147718947233437
# induced SNR: 0.42807061418828624
# SD(Y):  5.807778210393092
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 11
# 0.6 188 th simulation done
# seed: 1188
# Equally spaced quantile knots used.
# Main: 1.3427400198674264
# Interaction: 2.265690222761333
# induced SNR: 0.44568033206971613
# SD(Y):  6.582075572700932
# Naive Selected Groups: 4
# DS Selected Groups: 4
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.6 189 th simulation done
# seed: 1189
# Equally spaced quantile knots used.
# Main: 1.3600477233858188
# Interaction: 2.2206948791508236
# induced SNR: 0.4246391893755691
# SD(Y):  5.563955173101812
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 190 th simulation done
# seed: 1190
# Equally spaced quantile knots used.
# Main: 1.3976148282030272
# Interaction: 2.3476548286880936
# induced SNR: 0.4736517020683871
# SD(Y):  6.086730682937507
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 191 th simulation done
# seed: 1191
# Equally spaced quantile knots used.
# Main: 1.400278911797624
# Interaction: 2.3714001988849955
# induced SNR: 0.48654371567245913
# SD(Y):  6.270597050487609
# Naive Selected Groups: 8
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 192 th simulation done
# seed: 1192
# Equally spaced quantile knots used.
# Main: 1.3147994695159466
# Interaction: 2.433169737672877
# induced SNR: 0.4842877512816666
# SD(Y):  6.144129626239543
# Naive Selected Groups: 5
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 5
# 0.6 193 th simulation done
# seed: 1193
# Equally spaced quantile knots used.
# Main: 1.410099190356712
# Interaction: 2.2790828115201833
# induced SNR: 0.4519013002330824
# SD(Y):  6.42547643016987
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 194 th simulation done
# seed: 1194
# Equally spaced quantile knots used.
# Main: 1.4810762825672834
# Interaction: 2.3993998304897235
# induced SNR: 0.5213874084736356
# SD(Y):  6.549064666287767
# Naive Selected Groups: 10
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 195 th simulation done
# seed: 1195
# Equally spaced quantile knots used.
# Main: 1.4896411109630219
# Interaction: 2.330756942585529
# induced SNR: 0.49884399854543365
# SD(Y):  5.799809986086385
# Naive Selected Groups: 7
# DS Selected Groups: 6
# Data Carving Randomization Used
# MLE Selected Groups: 7
# 0.6 196 th simulation done
# seed: 1196
# Equally spaced quantile knots used.
# Main: 1.4260360701696746
# Interaction: 2.4730139127812283
# induced SNR: 0.5340710505761675
# SD(Y):  5.998727630647992
# Naive Selected Groups: 7
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 9
# 0.6 197 th simulation done
# seed: 1197
# Equally spaced quantile knots used.
# Main: 1.4263317528222674
# Interaction: 2.4828990341717185
# induced SNR: 0.524828146754833
# SD(Y):  6.187753692204074
# Naive Selected Groups: 7
# DS Selected Groups: 7
# Data Carving Randomization Used
# MLE Selected Groups: 6
# 0.6 198 th simulation done
# seed: 1198
# Equally spaced quantile knots used.
# Main: 1.3890318425732486
# Interaction: 2.357537425882999
# induced SNR: 0.4767299931421424
# SD(Y):  6.0543467436289085
# Naive Selected Groups: 9
# DS Selected Groups: 8
# Data Carving Randomization Used
# MLE Selected Groups: 8
# 0.6 199 th simulation done
# seed: 1199
# Equally spaced quantile knots used.
# Main: 1.375982802169351
# Interaction: 2.311838555420073
# induced SNR: 0.46103913737755947
# SD(Y):  5.91677314310907
# Naive Selected Groups: 7
# DS Selected Groups: 5
# Data Carving Randomization Used
# MLE Selected Groups: 6

# %%
import joblib
joblib.dump([ds_rank_def_count, target_dict, pval_dict, MSE_dict, oper_char],
            'vary_corr.pkl', compress=1)
# Out:
# ['vary_corr.pkl']

# %%
import joblib
ds_rank_def_count, target_dict, pval_dict, MSE_dict, oper_char = joblib.load('vary_corr.pkl')

# %%
ds_rank_def_count
# Out:
# {0.0: 1, 0.2: 9, 0.4: 24, 0.6: 24}

# %%
#ds_rank_def_count, target_dict, pval_dict, MSE_dict, oper_char = joblib.load('toy_weak.pkl')

# %%
ds_rank_def_count
# Out:
# {0.0: 1, 0.2: 9, 0.4: 24, 0.6: 24}

# %%
plot_ecdfs(pval_dict, xaxis="$'rho'$")

# %%
## Plotting dict: SNR - Method - List of pvals
## Plotting dict: SNR - Method - List of pvals
filtered_dict = filter_pval_dict_new(target_dict, threshold = 0,
                                     operator=ge)

# %%
plot_ecdfs(filtered_dict, xaxis=r"$\rho_{cross}$")

# %%
my_palette = {"MLE": "#48c072",
                  "Naive": "#fc5a50",
                  "Data Splitting": "#03719c"}
sns.set_style("white", {'axes.facecolor': 'white',
                            'axes.grid': True,
                            'axes.linewidth': 2.0,
                            'grid.linestyle': u'--',
                            'grid.linewidth': 4.0,
                            'xtick.major.size': 5.0,
                            })

# %%
sns.pointplot(x=pd.DataFrame(oper_char)["rho"],
              y=pd.DataFrame(oper_char)["avg length"],
              hue=pd.DataFrame(oper_char)["method"], markers='o',
              palette=my_palette)
#plt.ylim(10,35)
plt.xlabel(r"$\rho_{cross}$")
plt.ylabel("Average Length")
# Out:
# Text(0, 0.5, 'Average Length')

# %%
sns.pointplot(x=pd.DataFrame(MSE_dict)["rho"],
              y=pd.DataFrame(MSE_dict)["MSE"],
              hue=pd.DataFrame(MSE_dict)["method"], markers='o',
              palette=my_palette)
#plt.ylim(25,30)
plt.xlabel(r"$\rho_{cross}$")
plt.ylabel("Test MSE")
# Out:
# Text(0, 0.5, 'Test MSE')

# %% [markdown]
# # Applying BY Correction to the p-values

# %%
from collections import defaultdict
from scipy.stats import false_discovery_control


def add_BY_pval_by_method_and_index(data):
    # Check if BYpval is there
    if "BYpval" in data.keys():
        return
    # Assuming your dictionary is named 'data' and structured as described
    methods = data['method']
    indices = data['index']
    pvals = data['pval']

    # Initialize default dictionaries to collect p-values and positions for each (method, index) pair
    pvals_dict = defaultdict(list)
    pos_dict = defaultdict(list)

    # Iterate over the data and populate the dictionaries
    for i, (method, index, pval) in enumerate(zip(methods, indices, pvals)):
        key = (method, index)
        pvals_dict[key].append(pval)
        pos_dict[key].append(i)

    # Initialize BYpvals array with the same length as pvals
    BYpvals = [0] * len(pvals)  # or use numpy.zeros_like(pvals) if pvals is a numpy array

    # Apply BY correction and assign back to positions
    for key in pvals_dict:
        pvals_list = pvals_dict[key]
        positions = pos_dict[key]
        corrected_pvals = false_discovery_control(pvals_list, method='by')
        for pos, by_pval in zip(positions, corrected_pvals):
            BYpvals[pos] = by_pval

    # Add BYpvals to the original data dictionary
    data['BYpvals'] = BYpvals

    # Now, pvals_dict contains lists of p-values for each unique (method, index) pair

# %%
add_BY_pval_by_method_and_index(target_dict)

# %% [markdown]
# # Calculating Thresholded Power

# %%
def calculate_thresholded_power(pvalue, targets, level, threshold=0.05,
                                operator=ge):
    pvalue = np.array(pvalue)
    targets = np.array(targets)
    non_null = operator(np.abs(targets), threshold)
    rejection = pvalue < level
    if np.sum(non_null) == 0:
        return 0
    else:
        true_rej = np.sum(non_null * rejection) / np.sum(non_null)

    return true_rej

def calculate_thresholded_power_df(targets_dict,
                                   threshold=0.1,
                                   level=0.1,
                                   operator=ge, 
                                   pval_key = "BYpvals"):
    grouped_targets = pd.DataFrame(targets_dict).groupby(['index',
                                                          'method', 'parameter'])
    power_df = {}
    power_df['parameter'] = []
    power_df['method'] = []
    power_df['thresholded power'] = []
    for name, group in grouped_targets:
        power_df['parameter'].append(name[2])
        power_df['method'].append(name[1])
        pvalues = group[pval_key]
        targets = group['target']
        power_df['thresholded power'].append(
            calculate_thresholded_power(pvalues, targets, level=level, 
                                        threshold=threshold, operator=operator))
    return power_df

# %%
def point_plot_power(oper_char_dfs, x_axis='p', hue='method', 
                     ylim_low=None, ylim_high=None, exclude_naive=True,
                     randomizer_scales=None, x_label=None):
    for i in range(len(oper_char_dfs)):
        oper_char_dfs[i] = oper_char_dfs[i].copy()
        if exclude_naive:
            oper_char_dfs[i] = oper_char_dfs[i][oper_char_dfs[i]['method'] != "Naive"]
    sns.set_style("white", {'axes.facecolor': 'white',
                            'axes.grid': True,
                            'axes.linewidth': 2.0,
                            'grid.linestyle': u'--',
                            'grid.linewidth': 4.0,
                            'xtick.major.size': 5.0,
                            })
    # sns.histplot(oper_char_df["sparsity size"])
    # plt.show()
    n_subplots = len(oper_char_dfs)
    # cols = int(np.ceil(n_subplots / 2))
    cols = n_subplots

    fig = plt.figure(figsize=(cols * 5, 6))

    my_palette = {"MLE": "#48c072",
                  "Naive": "#fc5a50",
                  "Data Splitting": "#03719c"}

    # Create each subplot
    for i in range(1, n_subplots + 1):
        # ax = fig.add_subplot(2, cols, i) #two rows
        ax = fig.add_subplot(1, cols, i)  # one row
        if hue is not None:
            sns.pointplot(x=oper_char_dfs[i-1][x_axis],
                          y=oper_char_dfs[i-1]['thresholded power'],
                          hue=oper_char_dfs[i-1][hue],
                          markers='o',
                          palette=my_palette,
                          ax=ax)
            ax.set_title("Randomizer Scale:" + str(randomizer_scales[i-1]))
        else:
            sns.pointplot(x=oper_char_dfs[i-1][x_axis],
                          y=oper_char_dfs[i-1]['thresholded power'],
                          markers='o',
                          palette=my_palette,
                          ax=ax)
        if ylim_low is not None and ylim_high is not None:
            ax.set_ylim([ylim_low, ylim_high])

        ax.legend().set_visible(False)

    handles, labels = ax.get_legend_handles_labels()
    # fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.2)

    fig.subplots_adjust(bottom=0.3)
    fig.legend(handles, labels, loc='lower center', ncol=n_subplots,
               prop={'size': 15})

    # cov_plot.legend_.remove()
    # len_plot.legend_.remove()

    # plt.suptitle("Changing n,p")
    plt.subplots_adjust(wspace=0.3, hspace=0.5)
    if x_label is not None:
        plt.xlabel(x_label)
    plt.show()

# %%
power_threshold = 1
power_df1 = calculate_thresholded_power_df(targets_dict=target_dict, 
                                           threshold=power_threshold, level=0.1,
                                           operator=ge, pval_key="BYpvals")

# %%
my_palette = {"MLE": "#48c072",
                  "Naive": "#fc5a50",
                  "Data Splitting": "#03719c"}

# %%
df = pd.DataFrame(power_df1)
#df = df[df["method"] != "Naive"]
sns.pointplot(x=df["parameter"],
              y=df["thresholded power"],
              hue=df["method"], markers='o',
              palette=my_palette)
plt.xlabel("Split ratio (r)")
plt.ylabel("Thresholded Power")
# Out:
# Text(0, 0.5, 'Thresholded Power')

# %%
power_threshold = 1
FDP_df1 = calculate_thresholded_power_df(targets_dict=target_dict,
                                           threshold=power_threshold, level=0.1,
                                           operator=le, pval_key="BYpvals")
point_plot_power(oper_char_dfs=[pd.DataFrame(FDP_df1)],
                 x_axis="parameter",
                 hue="method", ylim_high=0.1, ylim_low=0,
                 randomizer_scales=["Hessian"], exclude_naive=False,
                 x_label="Split ratio (r)")
